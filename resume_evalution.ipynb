# %%
import json

def extract_resume_details(resume):
    """Extract annotations from a single resume."""
    # Check if 'annotations' exists and is a list, default to an empty list otherwise
    annotations = resume.get("annotation", None)
    if annotations is None:
        annotations = []
    
    extracted_data = {}

    for annotation in annotations:
        # Check if 'label' exists and is non-empty
        if annotation.get('label'):
            label = annotation['label'][0]  # Assuming one label per annotation
            for point in annotation.get('points', []):  # Safely get 'points', default to empty list
                # Check if 'text' exists for each point
                if 'text' in point:
                    extracted_data.setdefault(label, []).append(point['text'])
        else:
            print(f"Warning: Missing label in annotation: {annotation}")

    return extracted_data

def process_resumes(file_path):
    """Process all resumes in the file."""
    with open(file_path, "r", encoding="utf-8") as file:
        resumes = json.load(file)
    
    all_resumes_data = []

    for idx, resume in enumerate(resumes, start=1):
        print(f"Processing Resume {idx}...")
        extracted_data = extract_resume_details(resume)
        all_resumes_data.append(extracted_data)

    return all_resumes_data

# Specify the path to your file
file_path = "data.json"

# Process the resumes
parsed_resumes = process_resumes(file_path)

# Display the parsed data for each resume
for idx, resume_data in enumerate(parsed_resumes, start=1):
    print(f"\nResume {idx}:")
    for field, values in resume_data.items():
        print(f"{field}: {', '.join(values)}")
# Out:
# Processing Resume 1...
# Processing Resume 2...
# Processing Resume 3...
# Processing Resume 4...
# Processing Resume 5...
# Processing Resume 6...
# Processing Resume 7...
# Processing Resume 8...
# Processing Resume 9...
# Processing Resume 10...
# Processing Resume 11...
# Processing Resume 12...
# Processing Resume 13...
# Processing Resume 14...
# Processing Resume 15...
# Processing Resume 16...
# Processing Resume 17...
# Processing Resume 18...
# Processing Resume 19...
# Processing Resume 20...
# Processing Resume 21...
# Processing Resume 22...
# Processing Resume 23...
# Processing Resume 24...
# Processing Resume 25...
# Processing Resume 26...
# Processing Resume 27...
# Processing Resume 28...
# Processing Resume 29...
# Processing Resume 30...
# Processing Resume 31...
# Processing Resume 32...
# Processing Resume 33...
# Processing Resume 34...
# Processing Resume 35...
# Processing Resume 36...
# Processing Resume 37...
# Processing Resume 38...
# Processing Resume 39...
# Processing Resume 40...
# Processing Resume 41...
# Processing Resume 42...
# Processing Resume 43...
# Processing Resume 44...
# Processing Resume 45...
# Processing Resume 46...
# Processing Resume 47...
# Processing Resume 48...
# Processing Resume 49...
# Processing Resume 50...
# Processing Resume 51...
# Processing Resume 52...
# Processing Resume 53...
# Processing Resume 54...
# Processing Resume 55...
# Processing Resume 56...
# Processing Resume 57...
# Processing Resume 58...
# Processing Resume 59...
# Processing Resume 60...
# Processing Resume 61...
# Processing Resume 62...
# Processing Resume 63...
# Processing Resume 64...
# Processing Resume 65...
# Processing Resume 66...
# Processing Resume 67...
# Processing Resume 68...
# Processing Resume 69...
# Processing Resume 70...
# Processing Resume 71...
# Processing Resume 72...
# Processing Resume 73...
# Processing Resume 74...
# Processing Resume 75...
# Processing Resume 76...
# Processing Resume 77...
# Processing Resume 78...
# Warning: Missing label in annotation: {'label': [], 'points': [{'start': 2585, 'end': 2590, 'text': 'Oracle'}]}
# Processing Resume 79...
# Processing Resume 80...
# Processing Resume 81...
# Processing Resume 82...
# Processing Resume 83...
# Processing Resume 84...
# Processing Resume 85...
# Processing Resume 86...
# Processing Resume 87...
# Processing Resume 88...
# Processing Resume 89...
# Processing Resume 90...
# Processing Resume 91...
# Processing Resume 92...
# Processing Resume 93...
# Processing Resume 94...
# Processing Resume 95...
# Processing Resume 96...
# Processing Resume 97...
# Processing Resume 98...
# Processing Resume 99...
# Processing Resume 100...
# Processing Resume 101...
# Processing Resume 102...
# Processing Resume 103...
# Processing Resume 104...
# Processing Resume 105...
# Processing Resume 106...
# Processing Resume 107...
# Processing Resume 108...
# Processing Resume 109...
# Processing Resume 110...
# Processing Resume 111...
# Processing Resume 112...
# Processing Resume 113...
# Processing Resume 114...
# Processing Resume 115...
# Processing Resume 116...
# Processing Resume 117...
# Processing Resume 118...
# Processing Resume 119...
# Processing Resume 120...
# Processing Resume 121...
# Processing Resume 122...
# Processing Resume 123...
# Processing Resume 124...
# Processing Resume 125...
# Processing Resume 126...
# Processing Resume 127...
# Processing Resume 128...
# Processing Resume 129...
# Processing Resume 130...
# Processing Resume 131...
# Processing Resume 132...
# Processing Resume 133...
# Processing Resume 134...
# Processing Resume 135...
# Processing Resume 136...
# Processing Resume 137...
# Processing Resume 138...
# Processing Resume 139...
# Processing Resume 140...
# Processing Resume 141...
# Processing Resume 142...
# Processing Resume 143...
# Processing Resume 144...
# Processing Resume 145...
# Processing Resume 146...
# Processing Resume 147...
# Processing Resume 148...
# Processing Resume 149...
# Processing Resume 150...
# Processing Resume 151...
# Processing Resume 152...
# Processing Resume 153...
# Processing Resume 154...
# Processing Resume 155...
# Processing Resume 156...
# Processing Resume 157...
# Processing Resume 158...
# Processing Resume 159...
# Processing Resume 160...
# Processing Resume 161...
# Processing Resume 162...
# Processing Resume 163...
# Processing Resume 164...
# Warning: Missing label in annotation: {'label': [], 'points': [{'start': 7878, 'end': 7882, 'text': 'B.B.M'}]}
# Processing Resume 165...
# Processing Resume 166...
# Processing Resume 167...
# Processing Resume 168...
# Processing Resume 169...
# Processing Resume 170...
# Processing Resume 171...
# Processing Resume 172...
# Processing Resume 173...
# Processing Resume 174...
# Processing Resume 175...
# Processing Resume 176...
# Processing Resume 177...
# Processing Resume 178...
# Processing Resume 179...
# Processing Resume 180...
# Processing Resume 181...
# Processing Resume 182...
# Processing Resume 183...
# Processing Resume 184...
# Processing Resume 185...
# Processing Resume 186...
# Processing Resume 187...
# Processing Resume 188...
# Processing Resume 189...
# Processing Resume 190...
# Processing Resume 191...
# Processing Resume 192...
# Processing Resume 193...
# Processing Resume 194...
# Processing Resume 195...
# Processing Resume 196...
# Processing Resume 197...
# Processing Resume 198...
# Processing Resume 199...
# Processing Resume 200...
# Processing Resume 201...
# Processing Resume 202...
# Processing Resume 203...
# Processing Resume 204...
# Processing Resume 205...
# Processing Resume 206...
# Processing Resume 207...
# Processing Resume 208...
# Processing Resume 209...
# Processing Resume 210...
# Processing Resume 211...
# Processing Resume 212...
# Processing Resume 213...
# Processing Resume 214...
# Processing Resume 215...
# Processing Resume 216...
# Processing Resume 217...
# Processing Resume 218...
# Processing Resume 219...
# Processing Resume 220...
# Processing Resume 221...
# Processing Resume 222...
# Processing Resume 223...
# Processing Resume 224...
# Processing Resume 225...
# Processing Resume 226...
# Processing Resume 227...
# Processing Resume 228...
# Processing Resume 229...
# Processing Resume 230...
# Processing Resume 231...
# Processing Resume 232...
# Processing Resume 233...
# Processing Resume 234...
# Processing Resume 235...
# Processing Resume 236...
# Processing Resume 237...
# Processing Resume 238...
# Processing Resume 239...
# Processing Resume 240...
# Processing Resume 241...
# Processing Resume 242...
# Processing Resume 243...
# Processing Resume 244...
# Processing Resume 245...
# Processing Resume 246...
# Processing Resume 247...
# Processing Resume 248...
# Processing Resume 249...
# Processing Resume 250...
# Processing Resume 251...
# Processing Resume 252...
# Processing Resume 253...
# Processing Resume 254...
# Processing Resume 255...
# Processing Resume 256...
# Processing Resume 257...
# Processing Resume 258...
# Processing Resume 259...
# Processing Resume 260...
# Processing Resume 261...
# Processing Resume 262...
# Processing Resume 263...
# Processing Resume 264...
# Processing Resume 265...
# Processing Resume 266...
# Processing Resume 267...
# Processing Resume 268...
# Processing Resume 269...
# Processing Resume 270...
# Processing Resume 271...
# Processing Resume 272...
# Processing Resume 273...
# Processing Resume 274...
# Processing Resume 275...
# Processing Resume 276...
# Processing Resume 277...
# Processing Resume 278...
# Processing Resume 279...
# Processing Resume 280...
# Processing Resume 281...
# Processing Resume 282...
# Processing Resume 283...
# Processing Resume 284...
# Processing Resume 285...
# Processing Resume 286...
# Processing Resume 287...
# Processing Resume 288...
# Processing Resume 289...
# Processing Resume 290...
# Processing Resume 291...
# Processing Resume 292...
# Processing Resume 293...
# Processing Resume 294...
# Processing Resume 295...
# Processing Resume 296...
# Processing Resume 297...
# Processing Resume 298...
# Processing Resume 299...
# Processing Resume 300...
# Processing Resume 301...
# Processing Resume 302...
# Processing Resume 303...
# Processing Resume 304...
# Processing Resume 305...
# Processing Resume 306...
# Processing Resume 307...
# Processing Resume 308...
# Processing Resume 309...
# Processing Resume 310...
# Processing Resume 311...
# Processing Resume 312...
# Processing Resume 313...
# Processing Resume 314...
# Processing Resume 315...
# Processing Resume 316...
# Processing Resume 317...
# Processing Resume 318...
# Processing Resume 319...
# Processing Resume 320...
# Processing Resume 321...
# Processing Resume 322...
# Processing Resume 323...
# Processing Resume 324...
# Processing Resume 325...
# Processing Resume 326...
# Processing Resume 327...
# Processing Resume 328...
# Processing Resume 329...
# Processing Resume 330...
# Processing Resume 331...
# Processing Resume 332...
# Processing Resume 333...
# Processing Resume 334...
# Processing Resume 335...
# Processing Resume 336...
# Processing Resume 337...
# Processing Resume 338...
# Processing Resume 339...
# Processing Resume 340...
# Processing Resume 341...
# Processing Resume 342...
# Processing Resume 343...
# Processing Resume 344...
# Processing Resume 345...
# Processing Resume 346...
# Processing Resume 347...
# Processing Resume 348...
# Processing Resume 349...
# Processing Resume 350...
# Processing Resume 351...
# Processing Resume 352...
# Processing Resume 353...
# Processing Resume 354...
# Processing Resume 355...
# Processing Resume 356...
# Processing Resume 357...
# Processing Resume 358...
# Processing Resume 359...
# Processing Resume 360...
# Processing Resume 361...
# Processing Resume 362...
# Processing Resume 363...
# Processing Resume 364...
# Processing Resume 365...
# Processing Resume 366...
# Processing Resume 367...
# Processing Resume 368...
# Processing Resume 369...
# Processing Resume 370...
# Processing Resume 371...
# Processing Resume 372...
# Processing Resume 373...
# Processing Resume 374...
# Processing Resume 375...
# Processing Resume 376...
# Processing Resume 377...
# Processing Resume 378...
# Processing Resume 379...
# Processing Resume 380...
# Processing Resume 381...
# Processing Resume 382...
# Processing Resume 383...
# Processing Resume 384...
# Processing Resume 385...
# Processing Resume 386...
# Processing Resume 387...
# Processing Resume 388...
# Processing Resume 389...
# Processing Resume 390...
# Processing Resume 391...
# Processing Resume 392...
# Processing Resume 393...
# Processing Resume 394...
# Processing Resume 395...
# Processing Resume 396...
# Processing Resume 397...
# Processing Resume 398...
# Processing Resume 399...
# Processing Resume 400...
# Processing Resume 401...
# Processing Resume 402...
# Processing Resume 403...
# Processing Resume 404...
# Processing Resume 405...
# Processing Resume 406...
# Processing Resume 407...
# Processing Resume 408...
# Processing Resume 409...
# Processing Resume 410...
# Processing Resume 411...
# Processing Resume 412...
# Processing Resume 413...
# Processing Resume 414...
# Processing Resume 415...
# Processing Resume 416...
# Processing Resume 417...
# Processing Resume 418...
# Processing Resume 419...
# Processing Resume 420...
# Processing Resume 421...
# Processing Resume 422...
# Processing Resume 423...
# Processing Resume 424...
# Processing Resume 425...
# Processing Resume 426...
# Processing Resume 427...
# Processing Resume 428...
# Processing Resume 429...
# Processing Resume 430...
# Processing Resume 431...
# Processing Resume 432...
# Processing Resume 433...
# Processing Resume 434...
# Processing Resume 435...
# Processing Resume 436...
# Processing Resume 437...
# Processing Resume 438...
# Processing Resume 439...
# Processing Resume 440...
# Processing Resume 441...
# Processing Resume 442...
# Processing Resume 443...
# Processing Resume 444...
# Processing Resume 445...
# Processing Resume 446...
# Processing Resume 447...
# Processing Resume 448...
# Processing Resume 449...
# Processing Resume 450...
# Processing Resume 451...
# Processing Resume 452...
# Processing Resume 453...
# Processing Resume 454...
# Processing Resume 455...
# Processing Resume 456...
# Processing Resume 457...
# Processing Resume 458...
# Processing Resume 459...
# Processing Resume 460...
# Processing Resume 461...
# Processing Resume 462...
# Processing Resume 463...
# Processing Resume 464...
# Processing Resume 465...
# Processing Resume 466...
# Processing Resume 467...
# Processing Resume 468...
# Processing Resume 469...
# Processing Resume 470...
# Processing Resume 471...
# Processing Resume 472...
# Processing Resume 473...
# Processing Resume 474...
# Processing Resume 475...
# Processing Resume 476...
# Processing Resume 477...
# Processing Resume 478...
# Processing Resume 479...
# Processing Resume 480...
# Processing Resume 481...
# Processing Resume 482...
# Processing Resume 483...
# Processing Resume 484...
# Processing Resume 485...
# Processing Resume 486...
# Processing Resume 487...
# Processing Resume 488...
# Processing Resume 489...
# Processing Resume 490...
# Processing Resume 491...
# Processing Resume 492...
# Processing Resume 493...
# Processing Resume 494...
# Processing Resume 495...
# Processing Resume 496...
# Processing Resume 497...
# Processing Resume 498...
# Processing Resume 499...
# Processing Resume 500...
# Processing Resume 501...
# Processing Resume 502...
# Processing Resume 503...
# Processing Resume 504...
# Processing Resume 505...
# Processing Resume 506...
# Processing Resume 507...
# Processing Resume 508...
# Processing Resume 509...
# Processing Resume 510...
# Processing Resume 511...
# Processing Resume 512...
# Processing Resume 513...
# Processing Resume 514...
# Processing Resume 515...
# Processing Resume 516...
# Processing Resume 517...
# Processing Resume 518...
# Processing Resume 519...
# Processing Resume 520...
# Processing Resume 521...
# Processing Resume 522...
# Processing Resume 523...
# Processing Resume 524...
# Processing Resume 525...
# Processing Resume 526...
# Processing Resume 527...
# Processing Resume 528...
# Processing Resume 529...
# Processing Resume 530...
# Processing Resume 531...
# Processing Resume 532...
# Processing Resume 533...
# Processing Resume 534...
# Processing Resume 535...
# Processing Resume 536...
# Processing Resume 537...
# Processing Resume 538...
# Processing Resume 539...
# Processing Resume 540...
# Processing Resume 541...
# Processing Resume 542...
# Processing Resume 543...
# Processing Resume 544...
# Processing Resume 545...
# Processing Resume 546...
# Processing Resume 547...
# Processing Resume 548...
# Processing Resume 549...
# Processing Resume 550...
# Processing Resume 551...
# Processing Resume 552...
# Processing Resume 553...
# Processing Resume 554...
# Processing Resume 555...
# Processing Resume 556...
# Processing Resume 557...
# Processing Resume 558...
# Processing Resume 559...
# Processing Resume 560...
# Processing Resume 561...
# Processing Resume 562...
# Processing Resume 563...
# Processing Resume 564...
# Processing Resume 565...
# Processing Resume 566...
# Processing Resume 567...
# Processing Resume 568...
# Processing Resume 569...
# Processing Resume 570...
# Processing Resume 571...
# Processing Resume 572...
# Processing Resume 573...
# Processing Resume 574...
# Processing Resume 575...
# Processing Resume 576...
# Processing Resume 577...
# Processing Resume 578...
# Processing Resume 579...
# Processing Resume 580...
# Processing Resume 581...
# Processing Resume 582...
# Processing Resume 583...
# Processing Resume 584...
# Processing Resume 585...
# Processing Resume 586...
# Processing Resume 587...
# Processing Resume 588...
# Processing Resume 589...
# Processing Resume 590...
# Processing Resume 591...
# Processing Resume 592...
# Processing Resume 593...
# Processing Resume 594...
# Processing Resume 595...
# Processing Resume 596...
# Processing Resume 597...
# Processing Resume 598...
# Processing Resume 599...
# Processing Resume 600...
# Processing Resume 601...
# Processing Resume 602...
# Processing Resume 603...
# Processing Resume 604...
# Processing Resume 605...
# Processing Resume 606...
# Processing Resume 607...
# Processing Resume 608...
# Processing Resume 609...
# Processing Resume 610...
# Processing Resume 611...
# Processing Resume 612...
# Processing Resume 613...
# Processing Resume 614...
# Processing Resume 615...
# Processing Resume 616...
# Processing Resume 617...
# Processing Resume 618...
# Processing Resume 619...
# Processing Resume 620...
# Processing Resume 621...
# Processing Resume 622...
# Processing Resume 623...
# Processing Resume 624...
# Processing Resume 625...
# Processing Resume 626...
# Processing Resume 627...
# Processing Resume 628...
# Processing Resume 629...
# Processing Resume 630...
# Processing Resume 631...
# Processing Resume 632...
# Processing Resume 633...
# Processing Resume 634...
# Processing Resume 635...
# Processing Resume 636...
# Processing Resume 637...
# Processing Resume 638...
# Processing Resume 639...
# Processing Resume 640...
# Processing Resume 641...
# Processing Resume 642...
# Processing Resume 643...
# Processing Resume 644...
# Processing Resume 645...
# Processing Resume 646...
# Processing Resume 647...
# Processing Resume 648...
# Processing Resume 649...
# Processing Resume 650...
# Processing Resume 651...
# Processing Resume 652...
# Processing Resume 653...
# Processing Resume 654...
# Processing Resume 655...
# Processing Resume 656...
# Processing Resume 657...
# Processing Resume 658...
# Processing Resume 659...
# Processing Resume 660...
# Processing Resume 661...
# Processing Resume 662...
# Processing Resume 663...
# Processing Resume 664...
# Processing Resume 665...
# Processing Resume 666...
# Processing Resume 667...
# Processing Resume 668...
# Processing Resume 669...
# Processing Resume 670...
# Processing Resume 671...
# Processing Resume 672...
# Processing Resume 673...
# Processing Resume 674...
# Processing Resume 675...
# Processing Resume 676...
# Processing Resume 677...
# Processing Resume 678...
# Processing Resume 679...
# Processing Resume 680...
# Processing Resume 681...
# Processing Resume 682...
# Processing Resume 683...
# Processing Resume 684...
# Processing Resume 685...
# Processing Resume 686...
# Processing Resume 687...
# Processing Resume 688...
# Processing Resume 689...
# Processing Resume 690...
# Processing Resume 691...
# Processing Resume 692...
# Processing Resume 693...
# Processing Resume 694...
# Processing Resume 695...
# Processing Resume 696...
# Processing Resume 697...
# Processing Resume 698...
# Processing Resume 699...
# Processing Resume 700...
# Processing Resume 701...
#
# Resume 1:
# Email Address: indeed.com/r/Afreen-Jamadar/8baf379b705e37c6, indeed.com/r/Afreen-Jamadar/8baf379b705e37c6
# Links: https://www.indeed.com/r/Afreen-Jamadar/8baf379b705e37c6?isid=rex-download&ikw=download-top&co=IN
# Skills: Database (Less than 1 year), HTML (Less than 1 year), Linux. (Less than 1 year), MICROSOFT
# ACCESS (Less than 1 year), MICROSOFT WINDOWS (Less than 1 year)
#
# ADDITIONAL INFORMATION
#
# TECHNICAL SKILLS:
#
# • Programming Languages: C, C++, Java, .net, php.
# • Web Designing: HTML, XML
# • Operating Systems: Windows […] Windows Server 2003, Linux.
# • Database: MS Access, MS SQL Server 2008, Oracle 10g, MySql.
# Graduation Year: 2016, 2017
#
# College Name: Shivaji University Kolhapur , CDAC ACTS
# Degree: Bachelor of Engg in Information Technology, PG-DAC
# Companies worked at: Cisco Networking
# Location: Sangli
# Name: Afreen Jamadar
#
# Resume 2:
# Skills: ❖ Operating Environment: […] Windows95/98/XP/NT
# ❖ Database Tool: SQL Management Studio (MSSQL), Business
# Development Studio, Visual studio 2005
# ❖ Database Language: SQL, PL/SQL
# ❖ Ticket Tracking Tool: Service Now
# ❖ Reporting Tools: MS Reporting Services, SAS
# ❖ Languages: C, C++, PL/SQL, Database (3 years), SQL (3 years), Sql Dba, SQL Database Administration, System Analysis, Design, SQL Database Administration, System Analysis, Design
# Graduation Year: 2012
# College Name: Indira Gandhi Institute Of Technology, B.Tech in Computer Science and Engineering in CSE
# Companies worked at: Microsoft Corporation, HCL Technologies, Microsoft Corporation, Microsoft Corporation, UNISYS, UNISYS
# Location: Bengaluru, Bengaluru, Bengaluru, Bengaluru
# Designation: SQL DBA Analyst, DBA Support Analyst, DBA Support Analyst, Operational Analyst (SQL DBA) Engineer, Operational Analyst (SQL DBA) Engineer
# projects:  Finance Support
# Email Address: indeed.com/r/Alok-Khandai/5be849e443b8f467, indeed.com/r/Alok-Khandai/5be849e443b8f467
# Years of Experience: 3.5 Years
# Name: Alok Khandai
#
# Resume 3:
# Links: https://www.linkedin.com/in/anvitha-d-rao-65a068a7, https://www.linkedin.com/in/anvitha-d-rao-65a068a7
# Skills:  Hadoop, IoT, MySQL, PostgreSQL, D3js, Hadoop and Spark, Gephi, CSS, C, C++, HTML/CSS, Java, Python, Javascript, CSS, HADOOP,  Hadoop, C++ , JAVA,  Hadoop
# Graduation Year: 2016, 2019, 2016, 2016, 2016
# Location: Bengaluru, Bengaluru, Bengaluru
# College Name: M S Ramaiah Institute of Technology, Arizona State University
# Degree: Bachelor of Engineering in Computer Science
# , Masters in Computer Science
#
# Email Address: indeed.com/r/Anvitha-Rao/9d6acc68cc30c71c, indeed.com/r/Anvitha-Rao/9d6acc68cc30c71c
# Companies worked at: SAP Labs, SAP Labs
# Designation: Automation developer, Automation developer
# Can Relocate to: Anywhere
# Name: Anvitha Rao
#
# Resume 4:
# Skills: interpersonal skills.,  communication,  communication, PMP trained six sigma yellow belt, the great ability of leadership., self starter,  Pro active, interpersonal skills.,  communication
# Links: https://www.linkedin.com/in/arjun-k-s-31388627/, https://www.linkedin.com/in/arjun-k-s-31388627/
# Graduation Year:
# 2011, 2014
# , 2014
#
# College Name: College Bangalore University, sikkim manipal university
# Degree: B.COM. in Marketing, Accountancy, mba in human resource, MBA
# Email Address: indeed.com/r/arjun-ks/8e9247624a5095b4, indeed.com/r/arjun-ks/8e9247624a5095b4
# Companies worked at: Infosys, oracle, Infosys, Infosys, Infosys, Infosys, oracle India Limited, oracle
# Designation: Process Specialist, senior program coordinator, Senior Program coordinator, Senior Program coordinator
# UNKNOWN: Tally 9.0
# Years of Experience:  6.8 years
# Location: Bangalore City
# Name: arjun ks
#
# Resume 5:
# Skills: • Languages - Python
#
# • Software/Tools - Selenium, WAF, Sauce Labs, Jenkins, Creo parametric 2.0, Catia V6, Ansys, ANSYS (Less than 1 year), CATIA (Less than 1 year), CREO (Less than 1 year), PARAMETRIC
# (Less than 1 year), PYTHON (Less than 1 year), Selenium, Selenium Webdriver, Testing,
# Functional Testing, Automation Testing, Regression Testing, Quality Assurance
# Location: Chennai, Chennai
# College Name: Sri Venkateswara College Of Engineering
# Email Address: indeed.com/r/Arun-Elumalai/26575d617d50ea04, indeed.com/r/Arun-Elumalai/26575d617d50ea04
# Degree: Bachelor of Engineering in Automobile Engineering
# Rewards and Achievements: Won The Rising Star Award for the year 2017
# Designation: QA Tester
# , QA Tester
# , QA Tester in Software Testing, QA Tester
#
# Companies worked at:
# Accenture
# Years of Experience: 15 Months
# Name: Arun Elumalai
#
# Resume 6:
# Skills: M.S. OFFICE,  DOEACC O LEVEL
# Address: Orissa, Orissa, Orissa, Orissa, Orissa, Orissa
# Degree: Board of Secondary Education , Accounting, Bachelor in Commerce
# , Master of Finance and Control in MFC
# Email Address: indeed.com/r/Ashalata-Bisoyi/cf02125911cfb5df, indeed.com/r/Ashalata-Bisoyi/cf02125911cfb5df
# Links: https://www.indeed.com/r/Ashalata-Bisoyi/cf02125911cfb5df?isid=rex-download&ikw=download-top&co=IN
# College Name: Government girls High school , Science College, Hinjilicut, Berhampur university, Khallikote Autonomous college
# Graduation Year: 2008, 2010, 2013, 2015
#
# Companies worked at: Oracle India Private Limited, Oracle India Private Limited, Oracle India Private Limited
# Years of Experience: 2 Year of experience
# Designation: Transaction Processor, Transaction Processor
# Location: Bengaluru
# Name: Ashalata Bisoyi
#
# Resume 7:
# Skills: • Programming Languages: Java & J2EE, PHP, Apache Nifi, SOAP Web Services, Rest Web Services,
# Jackson-2
# • Framework's: Spring, Hibernate, Junit, Mockito
# • Database: MYSQL, SQL Server, Oracle
# • App/Web Servers: Tomcat, Apache
#
# • Operating Systems: Windows, Linux
# • SKM: Lithium
# • Tools: Git, JIRA, Eclipse, putty
#
# Knowledge Purview
#
# • Methodologies and Principles:
# ◦ Code Generation Tools
# ◦ Documentation Generation
# ◦ Inversion of Control
# ◦ Iterative Development
# ◦ Object Oriented Programming
# ◦ Deployment
# ◦ Agile
#
# Professional Experience
#
# Core Competencies
#
# ~ Requirement Gathering
# ~ Deployment & Support
# ~ Project Management
# ~ Software Development Life Cycle
# ~ Delivery Management
# ~ Quality Assurance
# ~ Application / Software Development
# ~ Liaison & Coordination, database (Less than 1 year), Git (Less than 1 year), Java (Less than 1 year), JIRA (Less than 1
# year), life cycle (Less than 1 year)
# Graduation Year: 2014
# College Name: Jawaharlal Nehru Technology University
# Degree: Bachelor of Technology in ECE
#
# Designation: Team Lead, Team Lead, Team Lead, Team Lead, Team Lead
# Email Address: indeed.com/r/Ashok-Kunam/7aac8767aacf10a0, indeed.com/r/Ashok-Kunam/7aac8767aacf10a0
# Companies worked at: Microsoft, Microsoft, Microsoft
# Years of Experience: 2.5 years
# Name: Ashok Kunam
#
# Resume 8:
# Skills: Bid management, Sales support, Requirement Analysis, Test Planning and Test execution, Requirement Analysis (Less than 1 year), Sales support (Less than 1 year), Test Planning (Less
# than 1 year)
# Graduation Year: 2015, 2008, 2008, 2015
# College Name: Great Lakes Institute of Management
# University: Guru Nanak Dev University
# Rewards and Achievements: Received STAR Certification for showcasing outstanding Soft Skills on 'Business & interpersonal
# communication
# Links: https://www.indeed.com/r/Avin-Sharma/3ad8a8b57a172613?isid=rex-download&ikw=download-top&co=IN
# Years of Experience: August 2008 to April 2013
# Companies worked at: Infosys Limited, Infosys Limited, Infosys Limited
# Designation: Senior System Engineer, Senior Associate Consultant, Senior Associate Consultant , Senior Associate Consultant
# Email Address: indeed.com/r/Avin-Sharma/3ad8a8b57a172613
#
# Location: Hyderabad
# Name: Avin Sharma
#
# Resume 9:
# Skills: * Sincere and Hardworking in nature
# * Highly Dedicated towards work
#
# * Efficient Individual and Team Player
# * Goal Oriented & Self Motivated
#
# IT Literacy
# Links: https://www.indeed.com/r/Ayesha-B/b2985be284dee3d6?isid=rex-download&ikw=download-top&co=IN
# Location: Bangalore, Bangalore, Bangalore, Bangalore, Bangalore
# College Name: Sindhi High School , Pre University Education, Atria Institute of Technology
# Degree: C.B.S.E., B.E. in CSE
# Companies worked at: Oracle, Oracle, Oracle, Oracle
# Designation: Team member, Team member
# Email Address: indeed.com/r/Ayesha-B/b2985be284dee3d6
#
# Name: Ayesha B
#
# Resume 10:
# Email Address: indeed.com/r/Ayushi-Srivastava/2bf1c4b058984738, indeed.com/r/Ayushi-Srivastava/2bf1c4b058984738
# Skills: CSS (Less than 1 year), DHCP (Less than 1 year), HSRP. (Less than 1 year), routing protocols.
# (Less than 1 year), Voip (2 years)
#
# College Name: Sumermal Jain Public School
# , HMR Institute of Technology and Management in Electronics and Communication
#
# Graduation Year: 2012, 2016, 2012, 2016
# Degree: Senior Secondary
# , B.Tech
# Companies worked at: Cisco -
# Designation: Senior Analyst
#
# Location: New Delhi
# Name: Ayushi Srivastava
#
# Resume 11:
# Skills: Teaching
# College Name: R.D.H.S. School, R.D.H.S. School, Government Science College
# Degree: Post Graduate Diploma in Clinical Data Management, H.S.C, B. Sc. in Biology
# Companies worked at: Oracle Clinical
# Designation: Class teacher, Preschool Teacher
# Location: Pune, Pune
# Email Address: indeed.com/r/Bhawana-Daf/d9ddb6a54519d583
#
# Name: Bhawana Daf
#
# Resume 12:
# Skills: Tally, Excel, Cloud application, Oracle application, Tally, Excel, Excel
# Companies worked at: Oracle, Accenture , Oracle, Oracle
# Graduation Year: 2010, 2013
# Degree: I D S G GOVT. College, B B M in Education, MBA in Finance
# College Name: Adhichunchanagiri Institute Of Technology
# Designation: Process associate
# , Financial Analyst, Financial Analyst
# Location: indeed.com/r/Darshan-G/025a61a82c6a8c5a
# , Bengaluru
# Name: Darshan G.
#
# Resume 13:
# Skills: Automation Testing Tools: Selenium WebDriver, Cucumber, Maven, Jenkins, Cyara
# Languages/Frameworks: JAVA, Data Driven, Hybrid, Page Object model, SOAP UI, JUnit, TestNG
# (TDD), Gherkin language (BDD), Cucumber, Log 4j
# Defect Tracking Tools: JIRA, HP ALM
# API Webservices Automation Skills: SOAP, REST, HttpClient, SOAP UI, XML, Jmeter, Postman
# Test Management Tools: HP ALM, Confluence page
# RDBMS: MySQL, Oracle, Mongo DB
# Source Control Management: SVN, GIT
# Operating Systems: Windows
# Domain Knowledge: E-commerce, Financial, Banking, Telecom, Billing, TESTING (9 years), JAVA (3 years), JUNIT (2 years), ORACLE (2 years), API (1 year)
#
# Graduation Year: 2008, 2008, 2008
# Location: Chennai, Chennai, Chennai, Chennai, Chennai, Chennai
# College Name: Sri Venkateshwara College of Engineering
# Degree: Bachelor's in Computer Science
# Designation: Technology Analyst, Technology Analyst, Technology Analyst
# Email Address: indeed.com/r/Dhanushkodi-Raj/cf31bbac6c5a5d29, indeed.com/r/Dhanushkodi-Raj/cf31bbac6c5a5d29
# Companies worked at: Infosys Limited
#
# Name: Dhanushkodi Raj
#
# Resume 14:
# Skills: AWS Devops
# College Name: Sri Venkateswara university tirupati
# Degree: BSC
# Companies worked at: cisco, Cisco, cisco, Cisco, Cisco
# Designation: software engineer, software engineer, Deployed chef for configuration management infrastructure, Deployed chef for configuration management infrastructure, Deployed chef for configuration management infrastructure
# Location: Bangalore, Bangalore, Bangalore, Bangalore
# Email Address: indeed.com/r/Dinesh-Reddy/139711455c45e1ad, indeed.com/r/Dinesh-Reddy/139711455c45e1ad
# Name: Dinesh Reddy
#
# Resume 15:
# Skills: Good team working ability,  Good presentation skills, Confident, Good Inter-Personal and Communication Skills, Keen learner, Disciplined, dedicated and hardworking, CSS, CSS, I.T Skills,  DATABASE, CSS, PROCUREMENT, BUYING, BUYING, ACCESS
# Graduation Year: 2009, 2011, 2014
# Location: Delhi, Delhi, Delhi, Delhi, Delhi, Delhi
# College Name: Crescent Public School -  New Delhi, Delhi, Crescent Public School -  New Delhi, Delhi, Bharati Vidyapeeth University -  Pune, Maharashtra
# , Punjab Technical University -  Chandigarh, Chandigarh
#
# Degree: BCA, MCA
# Designation: Co-coordinator of CODE HUNTER at CGC FEST
# , Co-coordinator of CODE HUNTER at CGC FEST
#
# Email Address: indeed.com/r/Dipesh-Gulati/17a483e9e19f9106
#
# Name: Dipesh Gulati
#
# Resume 16:
# Skills: problem solving (Less than 1 year), project lifecycle (Less than 1 year), project manager (Less
# than 1 year), technical assistance. (Less than 1 year)
# Graduation Year: 2007
# College Name: Saurashtra University
# Companies worked at: Microsoft , Microsoft , Microsoft , Microsoft , Microsoft , Microsoft , Microsoft , Microsoft , Microsoft , Microsoft , Microsoft
# Designation: Software Engineer
#
# Location: Indeed: indeed.com/r/Dushyant-
# Bhatt/140749dace5dc26f, Hyderabad
# Name: Dushyant Bhatt
#
# Resume 17:
# Companies worked at: Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Cloud Lending Solutions, Oracle, Oracle, Cloud Lending Solutions
# Skills: Languages: Core Java, Go Lang, Data Structures & Algorithms, Oracle
# PL-SQL programming, Sales Force with APEX.
# Tools: RADTool, Jdeveloper, NetBeans, Eclipse, SQL developer,
# PL/SQL Developer, WinSCP, Putty
# Web Technologies: JavaScript, XML, HTML, Webservice
#
# Operating Systems: Linux, Windows
# Version control system SVN & Git-Hub
# Databases: Oracle
# Middleware: Web logic, OC4J
# Product FLEXCUBE: Oracle FLEXCUBE Versions 10.x, 11.x and 12.x, APEX. (Less than 1 year), Data Structures (3 years), FLEXCUBE (5 years), Oracle (5 years),
# Algorithms (3 years)
#
# Graduation Year: 2012, 2012
# College Name: Adithya Institute of Technology
# Degree: B.E in Computer Science Engineering
# Designation: Associate Consultant, Staff Consultant, Senior Consultant
# , Senior Software Engineer
# , Senior Software Engineer
#
# Email Address: indeed.com/r/Govardhana-K/
# b2de315d95905b68
#
# Location: Bengaluru
# Name: Govardhana K
#
# Resume 18:
# Companies worked at: Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle
# Skills: Functional Testing, Blue Prism, Qtp
#
# College Name:
# Osmania University
# ,
# Osmania University
#
# Degree: B.Sc. in Computer Science, MCA
# Designation: QA Analyst, Test Analyst, Test Analyst, QA Analyst, Manual and Automation testing., Test Analyst
# Location: Hyderabad, Hyderabad, Hyderabad, Hyderabad, Hyderabad, Hyderabad, Hyderabad
# Years of Experience: 6 Yrs
# Name: Harini Komaravelli
#
# Resume 19:
# Skills:  Languages & Technologies: Python, R, SQL, NoSQL, Predictive Modelling,
# Market Basket Analysis, Sentimental Analysis, Clustering, Bash
# Scripting (Preliminary), Socket Programming, Java (Preliminary)
#
# • Tools: R Studio, Jupyter, GIT, Sublime, MATLAB, Linux, KVM, Virtual Box,
# Open VZ, Oracle SQL Developer, MySQL, MongoDB, Excel, Python (2 years), SQL. (1 year), NOSQL (1 year), R (2 years), Machine Learning (2 years)
#
# Email Address: indeed.com/r/Hartej-Kathuria/04181c5962a4af19, indeed.com/r/Hartej-Kathuria/04181c5962a4af19
# Graduation Year: 2016, 2018
# College Name: Manipal University
# , Manipal University
#
# Degree: B. Tech in Electrical and Electronics in Embedded Systems,
# Statistics and Probability
# Location: Bengaluru, Bengaluru
# Designation: Data Analyst Intern, Data Analyst Intern
# Companies worked at: Oracle Retail
#
# Name: Hartej Kathuria
#
# Resume 20:
# Skills: Languages: Core Java
# Front end/GUI Tools programming: Adobe Flex, GWT
# Database: Oracle 10g
# IDE: Eclipse, FlexBuilder
# FrameWorks: Spring(Basics), MVC frame work
# Operating System: Windows, Linux, Unix
# Graduation Year:  2009, 2011
# , 2011
#
# College Name: University College Of Engineering, Birla Institute Of Technology
# Degree: Bachelor of Technology in Computer Science
# Companies worked at: Oracle Corporation, Oracle Corporation, Oracle Corporation, State Street
# , Oracle Corporation, State Street
#
# Designation: Associate Consultant, Associate Consultant, Associate Consultant, Associate Consultant
# Email Address:  indeed.com/r/Ijas-
# Nizamuddin/6748d77f76f94eed
# Location: Irinchayam B.O
# Name: Ijas Nizamuddin
#
# Resume 21:
# Skills: rogramming Languages :C/C++, angular, java, java servlet, HTML, java script, MySQL, css, jsff.
#
# Operating Systems Linux, Windows, Android
#
# ORM Eclipse Link, Hibernate
#
# Framework & tools :ADF, Eclipse, Android Studio, Git, Selenium, Code blocks, Net beans, R studio,
# Tortoise SVN., JAVA (1 year), CSS (1 year), HTML (1 year), MYSQL (1 year), JAVASCRIPT (Less than 1 year),
# Angularjs (1 year), Oracle Pl/Sql
#
# Graduation Year:  2009,  2016,  2016
# College Name: Rashtriya Military School Bangalore, Rashtriya Military School Bangalore, Army institute of technology
# Degree: CBSE in Mathematics and English
# , Bachelor of Enginerring in Information Technology
# Location: Pune, Pune, Pune, Pune
# Companies worked at: Oracle Financial Software Services
# Designation: Application Developer, java developer
# Name: Imgeeyaul Ansari
#
# Resume 22:
# Graduation Year: 2011, 2013, 2011, 2017, 2011, 2011
# Degree: State Board, HSC in Computer science
# , BE (Computer Science) in Computer Science
#
# College Name: Acharya College Chembur, Saraswati College Of Engineering
# Skills: Capable and Hardworking, SQL Oracle -
# Companies worked at: NIIT
# Email Address: Indeed: indeed.com/r/Jay-
# Madhavi/1e7d0305af766bf6
# Location: Navi Mumbai
# Name: Jay Madhavi
#
# Resume 23:
# Graduation Year: 2011, 2014
# College Name: AG&SGS Intermediate College, Degree College
# Degree: B.com
#
# Companies worked at: SAP FICO, SAP FICO, SAP FICO, SAP FICO, SAP FICO, SAP FICO
# Designation: FI/CO Consultant in Tech Mahindra, FI/CO Consultant in Tech Mahindra
# Skills: Finance
# • Financial Accounting- General Ledger Accounting FI-G/L (New GL),
# • Accounts Payable-FI-A/P,
# • Accounts Receivable FI-A/R
# Years of Experience:  3.2-years
# Email Address:  indeed.com/r/Jitendra-Babu/bc3ea69a183395ed
# Location: Chennai
# Name: Jitendra Babu
#
# Resume 24:
# Skills: ITIL foundation
# College Name: Biju Patnaik University
# Degree: B. Tech in Electronics and Communication
#
# Companies worked at: Sap labs, Sap labs
# Designation:
# Associate consultant,
# Associate consultant,
# Associate consultant
# Email Address: indeed.com/r/Jyotirbindu-
# Patnaik/77e3ceda47fbb7e4
#
# Location: Bengaluru
# Name: Jyotirbindu Patnaik
#
# Resume 25:
# Skills: Consistent, Hard working,  Flexible, Ability to quick grasp the concepts, Destructive Testing (Less than 1 year), FORGE (Less than 1 year), Non-Destructive (Less than 1
# year), Non-Destructive Testing (Less than 1 year), quality control (Less than 1 year)
#
# College Name: Hr. Sec. School
# , Tamil Nadu Board Of Education, Velammal Engineering College
# Location: Rajapalaiyam, Rajapalaiyam
# Degree: B E in Production Engineering
# Companies worked at: Infosys Limited, Infosys Limited, Infosys Limited
# , Infosys Limited
# Designation: Systems Engineer, Systems Engineer
# Email Address: indeed.com/r/Karthihayini-
# C/627254c443836b3c
# Name: Karthihayini C
#
# Resume 26:
# Skills: Program Management (2 years), Product Management (2 years), Quality Assurance (10+
# years), Business intelligence, Devops
#
# Graduation Year: 2018, 2018
# College Name: Narsee Monjee Institute of Management Studies
# Degree: PGDBM
# Location: Hyderabad, Hyderabad, Hyderabad, Hyderabad, Hyderabad
# Companies worked at: Microsoft India, Microsoft India, Microsoft India, Microsoft India, Microsoft India, Microsoft India
# Designation: Sr Test Engineer, Sr consultant, Architect, Architect, Architect
# Name: Karthik GV
#
# Resume 27:
# Skills: Operating systems: Windows […] 8, 10.
# Languages: C, C++, C#
#
# PROFESSIONAL SKILL SET:
#
# • Good Communication Skills in English and Hindi.
# • Ability to work under pressure., SAP Security, SAP Systems: SAP ECC 6.0.
# Product Tools: GRC 10.1
# Database: Oracle, SQL, RDBMS., SAP Security, SAP Security
# College Name: Lovely Public Sr. Sec. School, Lovely Public Sr. Sec. School, Northern India engineering college, IP UNIVERSITY DELHI
# Degree: CBSE, CBSE, B.Tech in Engineering
# , B.Tech in Information Technology
# Graduation Year: 2011, 2015, 2015
# Location: Delhi, Delhi, Delhi, Delhi, Delhi
# Designation: Systems Engineer, Systems Engineer, Systems Engineer
# Companies worked at:  Infosys Ltd,  Infosys Ltd
# Email Address: indeed.com/r/Kartik-Sharma/cc7951fd7809f35e
#
# Name: Kartik Sharma
#
# Resume 28:
# Companies worked at: Cisco, Cisco, Cisco, Cisco, Cisco, Cisco, Cisco, Cisco, Cisco
# Skills: • Programming Languages: Python, XML
# • Database: Maria-DB, sql
# • Cisco Monitoring Tools: EM7
# • Operating Systems: Windows/XP
# • Reporting Tools: Vportal, Splunk
# • Application & Web Servers: Sciencelogic (EM7), Syslog sender, Relay server.
# • Data Structure Knowledge: Intermediate, Database (3 years), Python (3 years), Splunk (Less than 1 year), SQL (3 years), xml (3 years)
#
# Graduation Year: 2012
# College Name: rajasthan University
# , Compucom Insitute of Information Technology
#
# Designation: Team Member, Team Member, Team Member
# Location: Bengaluru, Bengaluru
# Email Address: Indeed: indeed.com/r/Kasturika-
# Borah/9e71468914b38ee8
# Name: Kasturika Borah
#
# Resume 29:
# Graduation Year: 2014, 2014
# College Name: REiume Institute of road, Networking, Infosys Limited
# Degree: Bachelor of Engineering in Information Technology, Foundation Training Program in Networking
#
# Companies worked at: Infosys Limited
# , Infosys Limited, Infosys Limited, Infosys Limited, Infosys Limited
# , Infosys Limited
# Email Address: indeed.com/r/Kavitha-K/8977ce8ce48bc800, indeed.com/r/Kavitha-K/8977ce8ce48bc800
# Designation: Senior System Engineer, Senior System Engineer , Senior System Engineer
# Location: Salem
# Name: Kavitha K
#
# Resume 30:
# Skills: Microsoft office, Libreoffice, Microsoft office, UART, Understanding of UART, AMBA protocol, coding, Knowledge of RTL coding, FSM based designs, HDL, Verilog HDL, UART, MS
# OFFICE, Microsoft office, HDL, coding, HDL, Verilog HDL, coding
# College Name: Vidyodaya P.U. College, Visvesvaraya Technological University
# , Srinivas Institute of Technology, Manipal Academy of Higher Education, School Of Information Sciences
# , Little Rock Indian School
#
# Degree: Bachelor of Engineering in Engineering, Master of Science in Technology in Technology
#
# School Of Information Sciences
# Email Address: indeed.com/r/Kavya-U/049577580b3814e6, indeed.com/r/Kavya-U/049577580b3814e6
# Graduation Year: 2007
# Location: Bengaluru, Bengaluru
# Companies worked at: Accenture
# Designation: Network Ops Associate
#
# Name: Kavya U.
#
# Resume 31:
# Skills: ANDROID (Less than 1 year), CISCO (Less than 1 year), NETWORKING (Less than 1 year)
# College Name: Silver Bells Public School -  Muzaffarnagar, Uttar Pradesh, Paratap Public School -  Karnal, Haryana, MM University
# Graduation Year: 2017
# Degree: B.Tech in CSE
# Companies worked at: SAP ABAP , SAP ABAP
# Location: Noida, Noida, Noida
# Designation: Developer, Developer
# Email Address: indeed.com/r/Khushboo-Choudhary/
# b10649068fcdfa42
#
# Name: Khushboo Choudhary
#
# Resume 32:
# Graduation Year: 2016, 2016, 2016
# Skills: network engineers, Networking, CCNA, knowledge of Active Directory, DHCP, DNS ,
# Troubleshooting and fix Network related issues (2 years)
#
# College Name: SSVPS’s Late B. S. Deore College of Engineering
# Degree: BE in computer science
# Location: Thane, Thane
# Companies worked at: SAP -
# Designation: Technical Support Engineer
# Can Relocate to: Anywhere
# Email Address: indeed.com/r/kimaya-
# sonawane/1f27a18d2e4b1948
# Name: kimaya sonawane
#
# Resume 33:
# Skills: Jira, Ansible, Jenkins, Splunk, Nagios, Docker, Python, AWS, Bamboo, Linux, Git, Chef, Windows,
# Powershell Scripting
# , Atlassian Tools: Jira, Confluence
# Configuration Management: Ansible /Chef
# CI Tools: Jenkins
# Monitoring Tools: Nagios
# Cloud: AWS
# Containerization: Docker
# Build Tools: Bamboo\Maven
# Log Tools: Splunk
# Databases: RDBMS, MYSQL, Oracle Database
# Programming Languages: Python and Java
# Scripting: Power Shell
# Operating Systems: Windows, Linux family, Redhat Linux
# Middleware: Websphere, Tomcat, Websphere MQ
# Graduation Year: 2008
# , 2010, 2014, 2010, 2014, 2014, 2014
# College Name: Sister Nivedita School , Lovely Professional University
# Location: Hyderabad, Hyderabad, Hyderabad, Hyderabad
# Degree: Board of Intermediate education, Secondary School Certificate in education
# , Bachelor Of Engineering in Mechanical Engineering
# Email Address: indeed.com/r/Koushik-Katta/a6b19244854199ec, indeed.com/r/Koushik-Katta/a6b19244854199ec
# Companies worked at: Infosys limited, Infosys limited
# Designation: DEVOPS ADMINISTRATOR
# Name: Koushik Katta
#
# Resume 34:
# Skills: DHCP (Less than 1 year), DNS (Less than 1 year), EXCHANGE (Less than 1 year), exchange
# (Less than 1 year), LAN (Less than 1 year)
#
# ADDITIONAL INFORMATION
#
# SKILLS:-
#
# • Messaging: MS exchange, Lotus client and MS outlook issue coordination to user.
#
# • Users / Share folders creation and permission assigning.
#
# • Networking: TCP/IP, DNS, DHCP, and LAN/WAN.
#
# • Monthly patching update activity and server owner approval / RFC follow-ups.
# College Name: inDR N.G.P ARTS AND SCIENCE COLLEGE
# Degree: Bachelor of computer science in computer science
#
# Companies worked at:
# Cisco
# Designation: Certified Network Associate Training Program, Certified Network Associate Training Program
# Email Address: indeed.com/r/Kowsick-
# Somasundaram/3bd9e5de546cc3c8
# Location: Erode
# Name: Kowsick Somasundaram
#
# Resume 35:
# Skills:
# SAPUI5 (2 years), CSS. (2 years), EMPLOYEE RESOURCE GROUP (2 years), ENTERPRISE
# RESOURCE PLANNING (2 years), SAP ABAP (2 years)
#
# ADDITIONAL INFORMATION
#
# Technical skills
# Languages SAPUI5 (Primary Skill),
# ABAP/4, C, C++, HTML, CSS, JavaScript, PHP,
# jQuery, Ajax.
# ERP SAP R/3 in 4.7, 5.0 (E)
# Operating Systems Windows
# Database MySQL, Oracle
# Location: Bengaluru, Bengaluru, Bengaluru, Bengaluru
# Companies worked at:  Infosys Limited,  Infosys Limited
# Designation: Senior Systems Engineer, Senior Systems Engineer, Senior Systems Engineer, Senior Systems Engineer
# Email Address: indeed.com/r/Lakshika-
# Neelakshi/27b31f359c52ef76
# Name: Lakshika Neelakshi
#
# Resume 36:
# Graduation Year: 2014, 2014, 2010, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014, 2014
# Skills: Tools: Manual Testing, Selenium (Selenium IDE, Selenium Web Driver), Eclipse IDE.
# Languages: C, Core Java
# Database: SQL
# Operating Systems: Windows XP, 7, 8
# Management Tool: HP Quality Center
# Defect Tracking Tool: JIRA
# College Name: Padmavani High School
# , Vani Jr college, Kuppam Engineering College
# Degree: B-Tech
# Designation: Software Test Engineer
# , Software Test Engineer
# , Software Test Engineer
#
# Companies worked at: Infosys Limited, Infosys Limited, Infosys Limited
# Email Address: indeed.com/r/Madas-
# Peddaiah/557069069de72b14
#
# Location: Anantapur
# Name: Madas Peddaiah
#
# Resume 37:
# Skills: LINUX (4 years), UNIX (4 years), ospf (4 years), bgp (4 years), mpls (4 years), ipsec (4 years),
# multicast (4 years), l2vpn (4 years), l3vpn (4 years), tcl (4 years), python (2 years)
#
# College Name: Rajah college
# , PES college
# Degree: S.S.C in computer science, Master degree in computer science in computer science
# Companies worked at: Cisco, Cisco, Wipro, Wipro, Cisco, Cisco, Wipro
# Designation: Senior software engineer
# , Senior project engineer, Senior project engineer, Senior project engineer
# Years of Experience: 4 year
# Email Address: Indeed: indeed.com/r/Madhuri-
# Sripathi/04a52a262175111c
#
# Location: Banglore
# Name: Madhuri Sripathi
#
# Resume 38:
# Skills:
# • Desk Manuals/Business Process & Navigation Documentation
# • Business Ethics
# • Professional Communication
# • Reporting Tools & Microsoft Office Applications, BCP (6 years), Data Governance (6 years), Data Management (6 years), Oracle (6 years),
# Reporting Tools (6 years)
#
# ADDITIONAL INFORMATION
#
# Key Skills
# • Process Management & Improvement
# • Operations & Team Management
# • Data Governance & Automation
# • Oracle E- Business Systems experience in Supplier Data/Vendor Data management
# • BCP Policies & Procedures
# Companies worked at: Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle, Oracle
# Email Address: indeed.com/r/Mahesh-Vijay/a2584aabc9572c30, indeed.com/r/Mahesh-Vijay/a2584aabc9572c30
# Graduation Year: 2004, 2007, 2007
# College Name: Vivekananda PU College, Vivekananda Degree College, Bangalore
# University
# Degree: Bachelors in Commerce (B.Com)
# Location: Bengaluru, Bengaluru
# Designation: Senior Analyst -Supplier Data Management, Lead Analyst -SME -Supplier Data Management
# , Team lead , Team lead
# Years of Experience: 6.5 years
# Name: Mahesh Vijay
#
# Resume 39:
# Skills: Uft/qtp,alm/qc,jira,jenkins,automation testing,cicd,service vitualization,uipath
#
#
#
# ADDITIONAL INFORMATION
#
# Operating Systems Windows 10 / 8 / 7 / Vista / XP
#
# Domains Banking and Finance
#
# Frameworks Data driven framework, Keyword driven framework
#
# Tools HP-UFT, HP-SV, HP-ALM/QC, SOAP UI, JENKINS, UiPath
#
# Methodologies STLC, Agile and waterfall.
#
# Project Management Tools JIRA
#
# TECHNICAL SKILLS
#
# • 2.5+years of professional experience in SQL.
# • Has hands on experience on Oracle DB (Oracle 11g)
# • Has extensive knowledge of Testing Procedures and various
# phases of Testing Has 2+ years of experience on QC/ALM
# • Has 2+ years working experience in API & GUI testing
# using HP UFT. Has 4 months of experience with uiPath
# • Has 2+ years working experience in SOAP UI.
# • Has 1.5+ year working experience on service virtualization using HP SV tool.
# • Has 6 months working experience in JIRA during work under agile methodology.
# • Has undergone Infosys Training in .Net Testing.
# • Has knowledge about CICD (Continuous integration and continuous delivery)
#
# PROJECT UNDERTAKEN
#
# DI-Middleware testing (August 14 -
# July 17) Domain- Accounts and customer.
# Client- ABN AMRO Bank (Netherland's bank)
# Project Name- ESB (Enterprise service bus)
# • Tools- ALM, SQL Developer, HP UFT, HP SV, SOAP UI, JENKINS, JIRA.
# In this project, we were validating end to end communication of consumer & provider via ESB.
# What consumer actually
# sent to the Provider and how provider responds to the consumer. Testing included System
# Integration Testing,
# Regression Testing, GUI Testing and Reports.
# Graduation Year: 2013
# College Name: Meghnad saha institute of technology
#
# Degree: B.Tech in CSE
# Designation: Software Automation Engineer
# , Software Automation Engineer
#
# Location: Pune,, Pune,
# Years of Experience: 3.5 years
# Email Address: indeed.com/r/Manisha-Bharti/3573e36088ddc073
#
# Name: Manisha Bharti
#
# Resume 40:
# Companies worked at: Accenture, Accenture, Accenture, Accenture, Accenture, Accenture
# Skills: QA (7 years), TESTING (6 years), ESTIMATION (6 years), AMDOCS (Less than 1 year), BILLING
# (Less than 1 year)
#
# ADDITIONAL INFORMATION
#
# SKILLS AND COMPETENCIES
# Domain and Functional Expertise Tools and Languages:
# • Telecommunications and IPTV Systems • NetCracker, NetProvision, Insight (IISY), HDM (Nokia),
# Trouble Ticketing
# • Test/QA Lead • Click Schedule, FieldLink, AMDOCS-Ordering, Billing - Product Catalog
# • Project Management • IBM - TOCP, Mediaroom, MediaFirst TV3 platform (Ericsson)
# ...
# Email Address: indeed.com/r/Pawar-susheelkumar/
# cc59051e8cad833a
# Name: Pawar susheelkumar
#
# Resume 673:
# Skills: ORACLE, LINUX, INTEGRATOR, INTEGRATION
# College: JNTU
# Degree: Bachelor Of Technology( Computer Science)
# projects: Klondike (Business Data integration & Datawarehouse Solution)
# Companies worked at: Reinsurance Claim WorkStation, Reinsurance Claim WorkStation, Infosys Technology Ltd, Infosys Technology Ltd, Infosys Technology Ltd, Infosys Technology Ltd, Infosys Technology Ltd, Infosys Technology Ltd, Infosys Technology Ltd, Infosys Technology Ltd, Infosys Technology Ltd, Infosys Technology Ltd, NTT Data Services, NTT Data Services, NTT Data Services, NTT Data Services, NTT Data Services, NTT Data Services
# Designation: assist Claim handler, assist Claim handler, Trainee, Developer/Lead Developer, Software Designer, Software Designer, Senior GIS Consultant, Technical Lead, Technical Lead, Project Manager, Software Development Advisor/Lead, Software Development Technical Manager, Software Development Technical Manager - II, Software Development Technical Manager, Software Development Associate Director, Software Development Associate Director
# Location: Bengaluru, Bengaluru, Bengaluru
# Links: https://www.indeed.com/r/Prathap-Kontham/4dd60802da7b8057?isid=rex-download&ikw=download-top&co=IN, https://www.indeed.com/r/Prathap-Kontham/4dd60802da7b8057?isid=rex-download&ikw=download-top&co=IN
# Can Relocate to: Hyderabad
# Email Address: indeed.com/r/Prathap-
# Kontham/4dd60802da7b8057
# Name: Prathap Kontham
#
# Resume 674:
# Email Address: indeed.com/r/Rahul-Kumar/427855a9dada03d9, indeed.com/r/Rahul-Kumar/427855a9dada03d9
# Skills: ATP engineer, Software Testing, network installation, circuit designing, Instrumentation, ATP engineer
# College: WBUT -  Durgapur
# Degree: B.tech in Electronics and communication engineering
# Companies worked at: A.V.Telcom
# Designation: Network installation, ATP engineer
# Can Relocate to: Anywhere
# Location: Bengaluru
# Name: Rahul Kumar
#
# Resume 675:
# Email Address: indeed.com/r/Rajat-Singh/13d2c2891cf0c1cd, indeed.com/r/Rajat-Singh/13d2c2891cf0c1cd
# Certifications: Android workshop
# Skills: Css, Php, Sql Dba, Html
# College: Rajshree school of management and technology, Mahatma gandhi kashi vidyaputh
# Degree: Master of Computer Applications (MCA), BSc in Math,physics, chemistry
# Location: Varanasi, Varanasi, Varanasi, Varanasi, Varanasi
# Companies worked at: TCS
# Designation: It freshar
# Name: Rajat Singh
#
# Resume 676:
# College: Delhi University
# Degree: B.A.
# Location: New Delhi, New Delhi, New Delhi, New Delhi, New Delhi, New Delhi, New Delhi, New Delhi, New Delhi, New Delhi, New Delhi, New Delhi, New Delhi, New Delhi
# Companies worked at: Hindustan Times, Hindustan Times, I-Process Services India (P) Ltd, Jagannath International Management School, Jagannath International Management School
# Designation: Computer Operator, Computer Operator, HR Executive, Academic Assistant, Academic Assistant
# Email Address: indeed.com/r/Sachin-Kumar/80211a4dde990ddd, indeed.com/r/Sachin-Kumar/80211a4dde990ddd
# Can Relocate to: Haryana, Gurgaon
# Name: Sachin Kumar
#
# Resume 677:
# College: Pt. DDU University, Annamalai University, Dr. B.R. Ambedkar University
# Degree: B.Com., M.Com. in Entrepreneurship, M.B.A. in Marketing
# Companies worked at: Standard Chartered Bank, Pidilite Industries Ltd, Emaar MGF Land Limited, Shipra Estate Ltd, Shipra Estate Ltd
# Designation: BUSINESS DEVELOPING EXECUTIVE, MODERN TRADE, BVG, MANAGER, ZONAL BUSINESS HEAD (RURBAN), ZONAL BUSINESS HEAD (RURBAN), MANAGER, SR. MANAGER (SALES), MANAGER, SR. MANAGER (SALES), MANAGER, ASSISTANT GENERAL MANAGER, MANAGER, ASSISTANT GENERAL MANAGER, MANAGER, ASSISTANT GENERAL MANAGER
# Location: Chandigarh, Chandigarh, Chandigarh, Chandigarh, Chandigarh
# Can Relocate to: Lucknow, Uttar Pradesh
# Email Address: indeed.com/r/Abhishek-
# Tripathi/63a09a1ba6a9a66a
# Name: Abhishek Tripathi
#
# Resume 678:
# Can Relocate to: Kerala, Kerala, Kerala, Kerala, Kerala, Kerala, Kerala, Kerala
# College: Visveswaraiah Technological University
# Degree: Bachelor of Engineering in E&C
# Companies worked at: Redington India Limited, Cisco Systems, Inc, Dell International Services India Pvt Ltd, Dell International Services India Pvt Ltd, Lenovo India Pvt Ltd, Lenovo India Pvt Ltd
# Designation: Sales Manager, Sales Specialist, Inside Sales Account Manager, Inside Sales Account Manager, Territory Sales Account Manager, Territory Sales Account Manager, Sales Manager, Sales Manager, Sales Manager
# Location: Bangalore Urban, Bangalore Urban
# Email Address: indeed.com/r/Ashith-
# Sivanandan/3ee67a3b7d848c0b
# Name: Ashith Sivanandan
#
# Resume 679:
# Skills: DSO, Mail application: Microsoft office outlook
# , Internet knowledge: Yes, Operating Systems known: MS OFFICE, DSO, AXIS
# Degree: MBA, MBA, MBA, B.Com, MBA
# Location: Akola, Akola, Akola, Akola, Akola, Akola
# College: LRT College Of Commerce Akola Maharashtra, LRT College Of Commerce Akola Maharashtra, ICFAI National college
# Email Address: indeed.com/r/Mithun-Rathod/47b0fa697dcce51b, indeed.com/r/Mithun-Rathod/47b0fa697dcce51b
# Companies worked at: Methodex Systems Ltd, Dealer of Royal Enfield Two Wheeler Vehicles
# Designation: Sales Manager, Territory Sales Manager, Sales Manager, Sales Manager
# Name: Mithun Rathod
#
# Resume 680:
# Skills: AML , MARKETING, AML , SALES, SALES, DOCUMENTATION
# College: PES College affiliated, Punjabi university
# Degree: B.Sc. in Chemistry, Zoology & Biotechnology, M.Sc. in Biotechnology
# Companies worked at: Panacea Biotec Pvt Ltd, Aviva Life Insurance India PVT Limited, Aviva Life Insurance India PVT Limited, Aviva Life Insurance India PVT Limited
# Designation: Scientific Officer in production & Validation, Sales Manager, Sales Manager, Sales Manager
# Location: Kolkata, Kolkata, Kolkata, Kolkata, Kolkata
# Email Address: indeed.com/r/Prosenjit-Mitra/c26c452ea7e1b821, indeed.com/r/Prosenjit-Mitra/c26c452ea7e1b821
# Can Relocate to: Anywhere
# Name: Prosenjit Mitra
#
# Resume 681:
# Email Address: indeed.com/r/Rahul-Kumar/427855a9dada03d9, indeed.com/r/Rahul-Kumar/427855a9dada03d9
# Skills: ATP engineer, Software Testing, network installation, circuit designing, Instrumentation, ATP engineer
# College: WBUT
# Degree: B.tech in Electronics and communication engineering
# Companies worked at: A.V.Telcom
# Designation: Network installation, ATP engineer
# Can Relocate to: Anywhere
# Location: Bengaluru
# Name: Rahul Kumar
#
# Resume 682:
# Skills: SALES,  RETAIL,  RETAIL, PROCUREMENT, SALES, SALES, SALES, SALES
# Location: Calicut, Calicut, Calicut, Calicut
# College: Calicut University
# Degree: B.com in Commerce
# Companies worked at: MANAPPURAM FINANCE Ltd, MANAPPURAM FINANCE Ltd, Ulccs Ltd, PAVIZHAM HEALTHIER DIET P.LTD, KKR GROUP OF COMPANIES, KKR GROUP OF COMPANIES
# Designation: BRANCH MANAGER, ASSISTANT OFFICER, SITE OFFICER ASSISTANT, DEPUTY SALES MANAGER
# , TERRITORY SALES MANAGER, TERRITORY SALES MANAGER
# Email Address: indeed.com/r/Shibin-Raveendran/bc9e8962b30d7c1d, indeed.com/r/Shibin-Raveendran/bc9e8962b30d7c1d
# Name: Shibin Raveendran
#
# Resume 683:
# Skills: DISPATCH, MARKETING, MARKETING, DIGITAL MARKETING, DIGITAL CAMPAIGN, SALES
# University: Berhampur University
# Companies worked at: SPANCO Telesystems & Solutions Ltd, R N Infra Communications (P) Ltd, Vihaan Infrasystems Ltd, India Telecom Infra Ltd, Canon India, Canon India
# Designation: Logistic/SCM Manager/Project Coordinator, Head (SCM), Operation Manger, Manager (Sales), Manager (Sales)
# Email Address: indeed.com/r/Susant-Parida/c58a8cfc01f4c9f3, indeed.com/r/Susant-Parida/c58a8cfc01f4c9f3
# Location: Raurkela
# Name: Susant Parida
#
# Resume 684:
# Skills: POWERPOINT,  OUTLOOK, MS WORD, EXCEL, ACCESS
# Can Relocate to: Tamil Nadu, Tamil Nadu, Tamil Nadu, Tamil Nadu, Tamil Nadu, Tamil Nadu, Tamil Nadu
# Location: Chennai, Chennai, Chennai, Chennai, Chennai, Chennai, Chennai, Chennai, Chennai
# College: University of Madras, University of Madras, Pachiyappa's College, University of Madras
# Degree: B.A., M A
# Companies worked at: LASON INDIA LIMITED, SYBASE SOLUTIONS PVT LIMITED, ORIGIN IT AND FACILITY SOLUTIONS PVT LTD., SKF INDIA LIMITED, MICHELIN INDIA PVT LTD, SUDAYSHEELA CONSULTANCY AND SERVICES PVT LTD, SUDAYSHEELA
# CONSULTANCY AND SERVICES PVT LTD
# Designation: Junior Processor, Administration and HR Assistant, Administrative and HR Executive, Administrative and HR Executive, Assistant Manager, Assistant Manager, Assistant Manager, Assistant Manager
# Email Address: indeed.com/r/Udayakumar-
# Sampath/afb7c1df8ad450b0
# Name: Udayakumar Sampath
#
# Resume 685:
# state: Maharashtra, Maharashtra, Maharashtra, Maharashtra, Maharashtra, Maharashtra
# Email Address: indeed.com/r/K-Murty/fc213f4dc9bbcef9, indeed.com/r/K-Murty/fc213f4dc9bbcef9
# Name: K Murty
#
# Resume 686:
# Email Address: indeed.com/r/Irfan-Shaikh/0614e43a6f2f88ce, indeed.com/r/Irfan-Shaikh/0614e43a6f2f88ce
# Companies worked at: Spa. Castle
# Designation: Manager Sales
# Location: Anywhere, Ahmedabad
# Name: Irfan Shaikh
#
# Resume 687:
# Skills: RETAIL MARKETING, RETAIL, RETAIL, TRAINING, SALES, SALES
# College: Saurashtra University
# Degree: Bachelor in Commerce
# Location: Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat
# Companies worked at: MARUTI SALES CORP, WIPRO LTD, HPL INDIA LTD., FINOLEX CABLES LTD, VINAY SWITCHES
# Designation: Senior Sales Officer,
# Sales Executive, Sr.Sales Executive, Area Sales Manager, Area Sales Manager, Area Sales Manager
# Email Address: indeed.com/r/Jayesh-Joshi/33998dfebb39e19e, indeed.com/r/Jayesh-Joshi/33998dfebb39e19e
# Name: Jayesh Joshi
#
# Resume 688:
#
# Resume 689:
# College: Vikram University Ujjain
# Degree: BACHELOR OF ARTS
# Designation: Customer support executive, Assistant Manager Customer care, Team manager, Team manager, Territory Sales Manager, Territory Sales Manager, Territory Sales Manager
# Companies worked at: Serco Global Services, Serco Global Services, Bharti Airtel Limited, Bharti Airtel Limited, Bharti Airtel Limited
# Email Address: indeed.com/r/Prashant-Duble/c74087946d3e17f9, indeed.com/r/Prashant-Duble/c74087946d3e17f9
# Location: Jalgaon
# Name: Prashant Duble
#
# Resume 690:
# Skills: Relationship management, Business Development, Relationship management, Business Development, Business Development
# College: Haji Qadam Rasool School, (B.S.K) College
# Degree: Diploma in computer application, B.A
# Companies worked at: Academy of Maritime Studies Pvt ltd New Delhi, COUNTRY CLUB INDIA LIMITED, Reliance Digital Retail Ltd, Merik Health Food Pvt Ltd, Al Dukan Retailing company(FMCG)
# Designation: Diploma in Deck Cadet in Deck Cadet, Business Development Officer, Assistant Manager, Area Sales Manager, Area Sales Manager, Store Manager, Store Manager, Store Manager
# Email Address: indeed.com/r/Rayees-Parwez/a2c576bd71658aca, indeed.com/r/Rayees-Parwez/a2c576bd71658aca
# Can Relocate to: Anywhere
# Location: Mumbai, Mumbai
# Name: Rayees Parwez
#
# Resume 691:
# Skills: MS OFFICE
# state: Madhya Pradesh, Madhya Pradesh
# College: Jiwaji University, Jaipuria Institute of Management
# Degree: B.Sc. in Industrial Chemistry, PGDM in Marketing and HR
# Designation: Privilege Banker/Assistant Manager, Privilege Banker/Assistant Manager, Relationship Officer, Relationship Officer, Territory Sales Executive, Territory Sales Executive, Territory Sales Manager, Territory Sales Manager, Territory Sales Manager
# Companies worked at: ICICI Bank, Asian Paints Ltd, Ultratech Cement Ltd, Essar Oil Ltd, Essar Oil Ltd
# Email Address: indeed.com/r/Sachin-Kushwah/
# ed1caca66a163767
# Name: Sachin Kushwah
#
# Resume 692:
# Links: https://in.linkedin.com/in/sakshi-sundriyal-b2620715
# , https://in.linkedin.com/in/sakshi-sundriyal-b2620715
#
# College: Delhi University, Institute for Technology and Management
# Degree: BSc in Physics, MBA in Management
# Location: Mumbai, Mumbai
# Companies worked at: Business Octane Solution Pvt. Ltd, Benefits and rewards Services, Benefits and rewards Services
# Designation: Territory Manager, Manager- Sales, Manager- Sales
# Email Address: indeed.com/r/Sakshi-Sundriyal/
# df41264b0a9efddc
# Name: Sakshi Sundriyal
#
# Resume 693:
# Email Address: indeed.com/r/Vijat-Kumar/0e4c2eea2848e207, indeed.com/r/Vijat-Kumar/0e4c2eea2848e207
# College: C.C.S. University, GLOBLE INSTITUTE OF MANAGEMENT & TECHNOLOGY
# Degree: B.Sc. in final, PGDM in Management, PGDBM in sales
# Companies worked at: Syska Lights Pvt Ltd, Syska Lights Pvt Ltd
# Designation: Area sales Manager, Area sales Manager
# Location: Hasanpur
# Name: Vijat Kumar
#
# Resume 694:
# Email Address: indeed.com/r/Irfan-Shaikh/0614e43a6f2f88ce, indeed.com/r/Irfan-Shaikh/0614e43a6f2f88ce
# des: Manager Sales
# Can Relocate to: Anywhere
#
# Designation: Ahmedabad
# Name: Irfan Shaikh
#
# Resume 695:
# College: Saurashtra University
# Degree: Bachelor in Commerce
# Can Relocate to: Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat, Gujarat
# Companies worked at: MARUTI SALES CORP , WIPRO LTD, HPL INDIA LTD., FINOLEX CABLES LTD, VINAY SWITCHES
# Designation: Senior Sales Officer, Sales Executive, Sales Executive, Sr.Sales Executive, Area Sales Manager, Area Sales Manager, Area Sales Manager
# Location: Rajkot, Rajkot, Rajkot, Rajkot, Rajkot, Rajkot, Rajkot, Rajkot, Rajkot, Rajkot, Rajkot, Rajkot
# Email Address: indeed.com/r/Jayesh-Joshi/33998dfebb39e19e, indeed.com/r/Jayesh-Joshi/33998dfebb39e19e
# Name: Jayesh Joshi
#
# Resume 696:
# Location: Nagpur, Nagpur, Nagpur, Nagpur, Nagpur, Nagpur, Nagpur, Nagpur, Nagpur
# Skills: C++
# College: Nagpur university, Nagpur University
# Degree: B.COM, M COM
# Companies worked at: ICICI BANK LTD, MAGMA LEASING LIMITED, GE MONEY HOME LOANS, THOUSNAD MONEY MANTRA GROUP, BAJAJ FINSERV, BAJAJ FINSERV, ADITYA BIRLA FINANCE, ADITYA BIRLA FINANCE
# Designation: BUSINESS MANAGER, LOCATION HEAD, AREA SALES MANAGER, BUSINESS MANAGER, AREA SALES MANAGER, AREA SALES MANAGER, AREA SALES MANAGER, AREA SALES MANAGER, REGIONAL HEAD
# Email Address: indeed.com/r/K-Murty/fc213f4dc9bbcef9, indeed.com/r/K-Murty/fc213f4dc9bbcef9
# Can Relocate to: Hyderabad, Pune
# Name: K Murty
#
# Resume 697:
# College: Vikram University Ujjain
# Degree: BACHELOR OF ARTS
# Designation: Territory Sales Manager, Territory Sales Manager, Territory Sales Manager
# Email Address:  indeed.com/r/Prashant-Duble/c74087946d3e17f9
# Location: Jalgaon
# Companies worked at:  Bharti Airtel Limited
#
# Name: Prashant Duble
#
# Resume 698:
# Skills: Relationship management, Business Development, Relationship management, Business Development, Business Development
# College: (B.S.K) College ( Vinoba Bhave University), Academy of Maritime Studies Pvt ltd New Delhi
# Degree: B.A, Diploma in Deck Cadet in Deck Cadet
# Companies worked at: COUNTRY CLUB INDIA LIMITED, Reliance Digital Retail Ltd, Merik Health Food Pvt Ltd, Al Dukan Retailing company
# Designation: Business Development Officer, Assistant Manager, Area Sales Manager, Area Sales Manager, Store Manager, Store Manager, Store Manager
# Email Address: indeed.com/r/Rayees-Parwez/a2c576bd71658aca, indeed.com/r/Rayees-Parwez/a2c576bd71658aca
# Can Relocate to: Anywhere
# Location: Mumbai, Mumbai
# Name: Rayees Parwez
#
# Resume 699:
# Skills: MS OFFICE (Less than 1 year), Mis, Sales Management, Channel Sales, Marketing Management,
# Team Management
# Designation: Territory Sales Executive
# , Territory Sales Executive
#
#
# Resume 700:
# Links: https://in.linkedin.com/in/sakshi-sundriyal-b2620715, https://in.linkedin.com/in/sakshi-sundriyal-b2620715, https://www.indeed.com/r/Sakshi-Sundriyal/df41264b0a9efddc?isid=rex-download&ikw=download-top&co=IN, https://www.indeed.com/r/Sakshi-Sundriyal/df41264b0a9efddc?isid=rex-download&ikw=download-top&co=IN
# Skills: BUSINESS DEVELOPMENT , BUSINESS CASE, BUDGETING, ACCOUNT MANAGEMENT, KEY ACCOUNTS
# College: Delhi University, Institute for Technology and Management
# Degree: BSc in Physics, MBA in Management
# Location: Mumbai, Mumbai
# Companies worked at: Business Octane Solution Pvt. Ltd, Benefits and rewards Services, Benefits and rewards Services
# Designation: Territory Manager, Manager- Sales, Manager- Sales
# Years of Experience: 7+ years
# abc: Profile
# Email Address: indeed.com/r/Sakshi-Sundriyal/
# df41264b0a9efddc
#
# Name: Sakshi Sundriyal
#
# Resume 701:

# %%
output_file = "parsed_resumes.json"

with open(output_file, "w", encoding="utf-8") as file:
    json.dump(parsed_resumes, file, indent=4)

print(f"Parsed data saved to {output_file}")
# Out:
# Parsed data saved to parsed_resumes.json

# %% [markdown]
# start

# %%
import spacy
from sentence_transformers import SentenceTransformer, util
from transformers import pipeline
import json

# Load the NLP model for Named Entity Recognition (NER)
nlp = spacy.load("en_core_web_sm")

# Load the Sentence Transformer model for semantic matching
sentence_model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Load the summarization model from Hugging Face
summarizer = pipeline("summarization", model="t5-small")
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# c:\Users\Mouadh Fraj\anaconda3\lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Mouadh Fraj\.cache\huggingface\hub\models--sentence-transformers--paraphrase-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:02<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# c:\Users\Mouadh Fraj\anaconda3\lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Mouadh Fraj\.cache\huggingface\hub\models--t5-small. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# Device set to use cpu

# %% [markdown]
# 1. Load Resume Data from JSON File

# %%
input_file = "parsed_resumes.json"

# Function to read the resume data from the JSON file
def load_resume_data(file_path):
    with open(file_path, "r") as file:
        return json.load(file)

# Load the resume data from the input JSON file
resume_data = load_resume_data(input_file)

# %% [markdown]
# 2. Data Extraction and Preprocessing

# %%
# Function to extract and preprocess resume text from multiple resumes
def preprocess_resume(resume):
   # Get the resume details safely
    name = resume.get('Name', [''])[0]
    companies_worked_at = ', '.join(resume.get('Companies worked at', []))
    skills = ', '.join(resume.get('Skills', []))
    college_name = ', '.join(resume.get('College Name', []))
    degree = ', '.join(resume.get('Degree', []))  # Use a default empty string if key doesn't exist

    # Prepare the resume text
    resume_text = f"{name} has worked at {companies_worked_at}. " \
                  f"She has skills in {skills}. " \
                  f"Graduated from {college_name} with a degree in {degree}."
    return resume_text

# %% [markdown]
# 3. Resume Summarization (Using LLM)

# %%
# Function to summarize the resume
def summarize_resume(resume_text):
    summary = summarizer(resume_text, max_length=150, min_length=50, do_sample=False)
    return summary[0]['summary_text']

# %% [markdown]
# 4. Job Fit Score Calculation (Semantic Matching)

# %%
# Example job description for matching (optional)
job_description = """
We are looking for a Network Engineer with experience in Database technologies, Linux, C++, and Java.
The candidate should have a strong understanding of networking protocols and be able to work in a fast-paced environment.
"""

# Function to calculate the job fit score
def calculate_job_fit(resume_summary, job_description):
    # Encode both the resume summary and job description
    resume_embedding = sentence_model.encode(resume_summary, convert_to_tensor=True)
    job_description_embedding = sentence_model.encode(job_description, convert_to_tensor=True)
    
    # Compute cosine similarity
    cosine_similarity = util.pytorch_cos_sim(resume_embedding, job_description_embedding)
    return cosine_similarity.item()

# %% [markdown]
# 5. Feedback Generation

# %%
# Function to generate feedback based on the resume
def generate_feedback(resume, job_description):
    feedback = []

     # Safely get the 'Skills' key
    skills = resume.get("Skills", [])
    
    # Example feedback logic
    if "Java" not in skills:
        feedback.append("Consider adding Java-related skills to the resume.")
    if "Database" not in skills:
        feedback.append("Consider adding Database-related skills to the resume.")
    
    # Add more feedback logic here...

    
    return feedback

# %% [markdown]
# 6. Processing Multiple Resumes

# %%
# Process all resumes
output_data = []

for resume in resume_data:
    resume_text = preprocess_resume(resume)
    resume_summary = summarize_resume(resume_text)
    job_fit_score = calculate_job_fit(resume_summary, job_description)
    feedback = generate_feedback(resume, job_description)
    
    output_data.append({
        "Name": resume['Name'][0],
        "Resume Summary": resume_summary,
        "Job Fit Score": job_fit_score,
        "Feedback": feedback
    })
# Out:
# Your max_length is set to 150, but your input_length is only 127. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=63)
# Your max_length is set to 150, but your input_length is only 128. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# Your max_length is set to 150, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 99. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=49)
# Your max_length is set to 150, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 150, but your input_length is only 73. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 150, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 150, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 150, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 150, but your input_length is only 118. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=59)
# Your max_length is set to 150, but your input_length is only 76. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 150, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 150, but your input_length is only 79. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=39)
# Your max_length is set to 150, but your input_length is only 92. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 150, but your input_length is only 111. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 87. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 150, but your input_length is only 129. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# Your max_length is set to 150, but your input_length is only 145. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=72)
# Your max_length is set to 150, but your input_length is only 84. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 150, but your input_length is only 131. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Your max_length is set to 150, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 134. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 150, but your input_length is only 134. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 150, but your input_length is only 108. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 150, but your input_length is only 137. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Your max_length is set to 150, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Your max_length is set to 150, but your input_length is only 110. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=55)
# Your max_length is set to 150, but your input_length is only 106. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=53)
# Your max_length is set to 150, but your input_length is only 97. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=48)
# Your max_length is set to 150, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 150, but your input_length is only 105. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=52)
# Your max_length is set to 150, but your input_length is only 117. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 150, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Your max_length is set to 150, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 112. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# Your max_length is set to 150, but your input_length is only 70. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=35)
# Your max_length is set to 150, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Token indices sequence length is longer than the specified maximum sequence length for this model (566 > 512). Running this sequence through the model will result in indexing errors
# Your max_length is set to 150, but your input_length is only 130. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=65)
# Your max_length is set to 150, but your input_length is only 117. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=58)
# Your max_length is set to 150, but your input_length is only 147. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Your max_length is set to 150, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 149. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=74)
# Your max_length is set to 150, but your input_length is only 138. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=69)
# Your max_length is set to 150, but your input_length is only 87. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=43)
# Your max_length is set to 150, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 150, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Your max_length is set to 150, but your input_length is only 82. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=41)
# Your max_length is set to 150, but your input_length is only 142. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Your max_length is set to 150, but your input_length is only 147. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Your max_length is set to 150, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 150, but your input_length is only 72. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=36)
# Your max_length is set to 150, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 150, but your input_length is only 148. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=74)
# Your max_length is set to 150, but your input_length is only 101. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 150, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 150, but your input_length is only 43. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Your max_length is set to 150, but your input_length is only 81. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 150, but your input_length is only 38. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 150, but your input_length is only 134. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=67)
# Your max_length is set to 150, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 150, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 150, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 150, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 150, but your input_length is only 74. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 150, but your input_length is only 100. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=50)
# Your max_length is set to 150, but your input_length is only 38. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 150, but your input_length is only 32. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=16)
# Your max_length is set to 150, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Your max_length is set to 150, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 150, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 150, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 150, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Your max_length is set to 150, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 150, but your input_length is only 93. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=46)
# Your max_length is set to 150, but your input_length is only 94. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 150, but your input_length is only 49. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 150, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Your max_length is set to 150, but your input_length is only 75. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=37)
# Your max_length is set to 150, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Your max_length is set to 150, but your input_length is only 103. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=51)
# Your max_length is set to 150, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 150, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Your max_length is set to 150, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 150, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 150, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 150, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 150, but your input_length is only 77. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=38)
# Your max_length is set to 150, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Your max_length is set to 150, but your input_length is only 109. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=54)
# Your max_length is set to 150, but your input_length is only 95. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=47)
# Your max_length is set to 150, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 150, but your input_length is only 124. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=62)
# Your max_length is set to 150, but your input_length is only 147. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=73)
# Your max_length is set to 150, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 150, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Your max_length is set to 150, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Your max_length is set to 150, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Your max_length is set to 150, but your input_length is only 80. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=40)
# Your max_length is set to 150, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Your max_length is set to 150, but your input_length is only 85. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=42)
# Your max_length is set to 150, but your input_length is only 143. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=71)
# Your max_length is set to 150, but your input_length is only 128. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=64)
# Your max_length is set to 150, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 150, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Your max_length is set to 150, but your input_length is only 136. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=68)
# Your max_length is set to 150, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Your max_length is set to 150, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Your max_length is set to 150, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Temp1\ipykernel_5876\2443916033.py in <module>
#       9
#      10     output_data.append({
# ---> 11         "Name": resume['Name'][0],
#      12         "Resume Summary": resume_summary,
#      13         "Job Fit Score": job_fit_score,
#
# KeyError: 'Name'

# %% [markdown]
# 7. Output

# %%
# Print the final output for all resumes
print(json.dumps(output_data, indent=4))
# Out:
# [
#     {
#         "Name": "Afreen Jamadar",
#         "Resume Summary": "MICROSOFT ACCESS (Less than 1 year), Linux . Java, Java, .net, php. ADDITIONAL INFORMATION TECHNICAL SKILLS . graduated from Shivaji University Kolhapur with degree in Bachelor of Engg in Information Technology .",
#         "Job Fit Score": 0.41518211364746094,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Alok Khandai",
#         "Resume Summary": "alok Khandai has worked at Microsoft Corporation, HCL Technologies, Microsoft Corporation and UNISYS . she has skills in  operating environment: [...] Windows95/98/XP/NT  Database Tool: SQL Management Studio (MSSQL), Business Development Studio, Visual studio 2005 .",
#         "Job Fit Score": 0.41903814673423767,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Anvitha Rao",
#         "Resume Summary": "anvitha Rao has worked at SAP Labs . she has skills in Hadoop, IoT, MySQL, PostgreSQL, D3js, Hadoop and Spark, Gephi, CSS, C, C++, HTML/CSS, Java, Python, Javascript, CSS .",
#         "Job Fit Score": 0.33516502380371094,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "arjun ks",
#         "Resume Summary": "arjun ks has worked at Infosys, oracle, Infosies, InfoSys . she has skills in interpersonal skills., communication, communication . graduated from college Bangalore, sikkim manipal university with a degree in B.COM.",
#         "Job Fit Score": 0.33738085627555847,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Arun Elumalai",
#         "Resume Summary": "arun Elumalai has worked at Accenture . she has skills in languages - Python and software/tools . graduated from Sri Venkateswara college of engineering . graduated with a degree in Bachelor of Engineering in Automobile Engineering .",
#         "Job Fit Score": 0.280762255191803,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ashalata Bisoyi",
#         "Resume Summary": "Ashalata Bisoyi has worked at Oracle India Private Limited . she has skills in M.S. OFFICE, DOEACC O LEVEL . graduated from government girls high school , science college, Hinjilicut .",
#         "Job Fit Score": 0.2926749885082245,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ashok Kunam",
#         "Resume Summary": "Ashok Kunam has worked at Microsoft, Microsoft . she has skills in \u2022 Programming Languages: Java & J2EE, PHP, Apache Nifi, SOAP Web Services, Rest Web Services . graduated from Jawaharlal Nehru Technology University .",
#         "Job Fit Score": 0.42611926794052124,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Avin Sharma",
#         "Resume Summary": "Avin Sharma has skills in Bid management, Sales support, Requirement Analysis, Test planning and Test execution . graduated from Great Lakes Institute of Management with a degree in a . grading degree .",
#         "Job Fit Score": 0.2658787667751312,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ayesha B",
#         "Resume Summary": "Ayesha B has worked at Oracle, Oracle, and Oracle . she has skills in * Sincere and Hardworking in nature * Highly Dedicated towards work * Efficient Individual and Team Player * Goal Oriented & Self Motivated IT Literacy .",
#         "Job Fit Score": 0.3409520983695984,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ayushi Srivastava",
#         "Resume Summary": "ayushi Srivastava has worked at Cisco . she has skills in CSS (Less than 1 year), DHCP . hmr institute of technology and management in electronics and communication with a degree in senior secondary .",
#         "Job Fit Score": 0.46010807156562805,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Bhawana Daf",
#         "Resume Summary": "Bhawana Daf has worked at Oracle Clinical . Graduated from R.D.H.S. School with a degree in Post Graduate Diploma in Clinical Data Management . she has skills in Teaching and teaching skills .",
#         "Job Fit Score": 0.16355499625205994,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Darshan G.",
#         "Resume Summary": "Darshan G. has worked at Oracle, Accenture , Oracle, Oracle . she has skills in Tally, Excel, Cloud application, Oracle application, Tally . graduated from Adhichunchanagiri Institute of Technology with a degree in I D S G GOVT.",
#         "Job Fit Score": 0.35074707865715027,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Dhanushkodi Raj",
#         "Resume Summary": "Dhanushkodi Raj has worked at Infosys Limited . she has skills in Automation Testing Tools: Selenium WebDriver, Cucumber, Maven, Jenkins, Cyara Languages/Frameworks .",
#         "Job Fit Score": 0.34668564796447754,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Dinesh Reddy",
#         "Resume Summary": "Dinesh Reddy has worked at cisco, Cisco . she has skills in AWS Devops . graduated from Sri Venkateswara university tirupati with a degree in BSC .",
#         "Job Fit Score": 0.39493370056152344,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Dipesh Gulati",
#         "Resume Summary": "Dipesh Gulati has skills in Good team working ability, Good presentation skills, Confident, Good Inter-Personal and Communication Skills, Keen learner, Disciplined, dedicated and hardworking . graduated from Crescent Public School - new Delhi, Delhi, Bharati Vidyapeeth University - Pune, Maharashtra .",
#         "Job Fit Score": 0.17056356370449066,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Dushyant Bhatt",
#         "Resume Summary": "Dushyant Bhatt has worked at Microsoft , Microsoft, , microsoft , and others . she has skills in problem solving (Less than 1 year) and project lifecycle . graduated from saurashtra university with a degree in .",
#         "Job Fit Score": 0.24911536276340485,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Govardhana K",
#         "Resume Summary": "Govardhana K has a degree in B.E in Computer Science Engineering . she has skills in languages: Core Java, Go Lang, Data Structures & Algorithms, Oracle PL-SQL programming, Sales Force with APEX .",
#         "Job Fit Score": 0.36267173290252686,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Harini Komaravelli",
#         "Resume Summary": "Harini Komaravelli has a degree in B.Sc. in Computer Science . she has skills in Functional Testing, Blue Prism, Qtp . graduated from osmania university , Osmania University .",
#         "Job Fit Score": 0.2299184650182724,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Hartej Kathuria",
#         "Resume Summary": "Hartej Kathuria has worked at Oracle Retail . she has skills in languages & technologies: Python, R, SQL, NoSQL, Predictive Modelling, Market Basket Analysis, Sentimental Analysis, Clustering, Bash Scripting (Preliminary)",
#         "Job Fit Score": 0.2949126660823822,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ijas Nizamuddin",
#         "Resume Summary": "Ijas Nizamuddin has worked at Oracle Corporation, State Street . she has skills in languages: Core Java Front end/GUI Tools programming . graduated from university college of engineering, Birla Institute Of Technology .",
#         "Job Fit Score": 0.42843031883239746,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Imgeeyaul Ansari",
#         "Resume Summary": "Imgeeyaul Ansari has worked at Oracle Financial Software Services . she has skills in rogramming Languages :C/C++, angular, java servlet, HTML, script, MySQL, css .",
#         "Job Fit Score": 0.38861972093582153,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Jay Madhavi",
#         "Resume Summary": "Jay Madhavi has worked at NIIT . she has skills in Capable and Hardworking, SQL Oracle - . graduated from Acharya College Chembur, Saraswati College Of Engineering with a degree in state board, HSC in Computer science .",
#         "Job Fit Score": 0.39960578083992004,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Jitendra Babu",
#         "Resume Summary": "Jitendra Babu has worked at SAP FICO, . SAP . FICO . has skills in finance . she has a degree in B.com . graduated from AG&SGS Intermediate College, degree .",
#         "Job Fit Score": 0.23413918912410736,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Jyotirbindu Patnaik",
#         "Resume Summary": "Jyotirbindu Patnaik has worked at Sap labs . she has skills in ITIL foundation . graduated from biju Patnak university with a degree in B. tech in electronics and communication .",
#         "Job Fit Score": 0.35465317964553833,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Karthihayini C",
#         "Resume Summary": "Karthihayini C has worked at Infosys Limited . she has skills in Consistent, Hard working, Flexible, Ability to quick grasp the concepts . graduated from Hr. Sec. School , Tamil Nadu Board Of Education .",
#         "Job Fit Score": 0.24593579769134521,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Karthik GV",
#         "Resume Summary": "Karthik GV has worked at Microsoft India, Microsoft India . she has skills in Program Management (2 years), Product Management (22 years), Quality Assurance (10+ years), Business intelligence, devops . graduated from Narsee Monjee Institute of Management Studies with a degree in PGDBM.",
#         "Job Fit Score": 0.3227573335170746,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Kartik Sharma",
#         "Resume Summary": "Kartik Sharma has skills in operating systems: Windows [...] 8, 10. Languages: C, C++, C# PROFESSIONAL SKILL SET: \u2022 Good Communication skills in English and Hindi . graduated from Lovely Public Sr. Sec. School, Northern India engineering college, IP UNIVERSITY DELHI .",
#         "Job Fit Score": 0.2934070825576782,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Kasturika Borah",
#         "Resume Summary": "Kasturika Borah has worked at Cisco, Cisco, and Cisco . she has skills in \u2022 Programming Languages: Python, XML, SQL, xml . graduated from rajasthan university with a degree in information technology .",
#         "Job Fit Score": 0.35622280836105347,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Kavitha K",
#         "Resume Summary": "Kavitha K has worked at Infosys Limited . she has skills in . graduated from REiume Institute of road, Networking . a degree in Bachelor of Engineering in Information Technology, Foundation Training Program in Networking.",
#         "Job Fit Score": 0.36663949489593506,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Kavya U.",
#         "Resume Summary": "Kavya U. has worked at Accenture . she has skills in Microsoft office, Libreoffice, Microsoft office and coding . graduated from Vidyodaya P.U. College, Visvesvaraya Technological University .",
#         "Job Fit Score": 0.26267990469932556,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Khushboo Choudhary",
#         "Resume Summary": "Khushboo Choudhary has worked at SAP ABAP . she has skills in ANDROID (Less than 1 year), CISCO, NETWORKING . graduated from silver Bells Public School - Muzaffarnagar, Uttar Pradesh .",
#         "Job Fit Score": 0.3184416592121124,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "kimaya sonawane",
#         "Resume Summary": "kimaya sonawane has worked at SAP - . has skills in network engineers, Networking, CCNA, knowledge of Active Directory, DHCP, DNS , Troubleshooting and fix Network related issues (2 years)",
#         "Job Fit Score": 0.5125998258590698,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Koushik Katta",
#         "Resume Summary": "Koushik Katta has worked at Infosys limited . she has skills in Jira, Ansible, Jenkins, Splunk, Nagios, Docker, Python, AWS, Bamboo, Linux, Git, Chef, Windows .",
#         "Job Fit Score": 0.3630945682525635,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Kowsick Somasundaram",
#         "Resume Summary": "Kowsick Somasundaram has worked at Cisco . she has skills in DHCP, DNS, EXCHANGE, exchange, LAN, and LAN/WAN . graduated from inDR N.G.P ARTS AND SCIENCE COLLEGE .",
#         "Job Fit Score": 0.42189285159111023,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Lakshika Neelakshi",
#         "Resume Summary": "Lakshika Neelakshi has skills in SAPUI5 (2 years), CSS . 2 years, EMPLOYEE RESOURCE GROUP (2 years) ADDITIONAL INFORMATION Technical skills Languages SAPUI5, C++, HTML, CSS, JavaScript, PHP, jQuery, Ajax .",
#         "Job Fit Score": 0.19203145802021027,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Madas Peddaiah",
#         "Resume Summary": "Madas Peddaiah has worked at Infosys Limited . she has skills in Tools: Manual Testing, Selenium (Selenium IDE), Eclipse IDE . graduated from Padmavani high school .",
#         "Job Fit Score": 0.25167199969291687,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Madhuri Sripathi",
#         "Resume Summary": "Madhuri Sripathi has worked at Cisco, Cisco, Wipro, wipro . has skills in UNIX (4 years), ospf (4 years) and mpls (4 years). graduated from Rajah college .",
#         "Job Fit Score": 0.4392688274383545,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Mahesh Vijay",
#         "Resume Summary": "Mahesh Vijay has worked at Oracle, Oracle, oracles . she has skills in Business Ethics and Professional Communication . ADDITIONAL INFORMATION Key Skills \u2022 Process Management & Improvement \u2022 Operations & Team Management \u2022 Data Governance & Automation .",
#         "Job Fit Score": 0.29793500900268555,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Manisha Bharti",
#         "Resume Summary": "Manisha Bharti has skills in Uft/qtp,alm/qc,jira,jenkins,automation testing,cicd,service vitualization,uipath ADDITIONAL INFORMATION Operating Systems Windows 10 / 8 / 7 / Vista / XP Domains Banking and Finance Frameworks Data driven framework .",
#         "Job Fit Score": 0.2633990943431854,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Manjari Singh",
#         "Resume Summary": "Manjari Singh has skills in QA (7 years), TESTING (6 years), AMDOCS (Less than 1 year), BILLING (6 years) ADDITIONAL INFORMATION SKILLS AND COMPETENCIES Domain and Functional Expertise Tools and Languages: Telecommunications and IPTV Systems .",
#         "Job Fit Score": 0.25855135917663574,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Mohamed Ameen",
#         "Resume Summary": "Mohamed Ameen has worked at Accenture . she has skills in Active Directory (2 years), Microsoft office, Windows,End user computing (3 years). graduated from Rajiv Gandhi Institute of Technology, al-Ameen PU College, Visveswaraiah Technological University .",
#         "Job Fit Score": 0.3398503363132477,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Mohini Gupta",
#         "Resume Summary": "Mohini Gupta has worked at Microsoft, Microsoft . she has skills in active directory, iis, sccm, dhcp, sql, wsus ADDITIONAL INFORMATION Computer skills .",
#         "Job Fit Score": 0.3845064640045166,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Navas Koya",
#         "Resume Summary": "Navas Koya has skills in ASP.NET, C#, QA tools, Coding and modularization . she has a degree in computer application from a university in california . graduated with a bachelor of computer application .",
#         "Job Fit Score": 0.33505645394325256,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Navjyot Singh Rathore",
#         "Resume Summary": "Navjyot Singh Rathore has worked at Accenture . she has skills in Basic Computers knowledge . completed project work on working capital with A+ grade . graduated from Guru Nanak English high school and Jr cllg .",
#         "Job Fit Score": 0.3075430989265442,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Nazish Alam",
#         "Resume Summary": "Nazish Alam has skills in \u2022 Trained on SAP S4 HANA . Having knowledge of Code Push down, CDS view and it's consumption in ABAP . has knowledge of SQL, DDL, DML syntaxes .",
#         "Job Fit Score": 0.22748500108718872,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Nidhi Pandit",
#         "Resume Summary": "Nidhi Pandit has worked at Infosys Limited . she has skills in Technical Experience: - Automation Testing (REST API, Service Virtualization), Functional Testing, Regression Testing Manual Testing, Scripting (SQL)",
#         "Job Fit Score": 0.37563371658325195,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Nikhileshkumar Ikhar",
#         "Resume Summary": "Nikhileshkumar Ikhar has worked at Infosys, Cisco, Cisco . she has skills in Platform business model, Python, Django, Celery, Java, AngularJS, HTML, Bootstrap 3, Shell Script, MySQL, MongoDB . graduated from IIIT, VIT with a degree in M.Tech. in IT .",
#         "Job Fit Score": 0.46990498900413513,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Nitin Tr",
#         "Resume Summary": "Nitin Tr has worked at Oracle, Oracle . she has skills in \u2022 Programming Language: core java, peoplecode. \u2022 Scripting languages: PHP, JavaScript. \u2022 Web Languages: HTML, CSS. \u2022 Database Language: Sql.",
#         "Job Fit Score": 0.42649006843566895,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Pradeeba V",
#         "Resume Summary": "Pradeeba V has worked at CISCO . she has skills in REST, Angular JS, DOJO, CSS, HTML, SVN, code Collaborator, WinSCP, SSH, Eclipse, UNIX, Windows 7 .",
#         "Job Fit Score": 0.38260093331336975,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Prakriti Shaurya",
#         "Resume Summary": "Prakriti Shaurya has worked at Infosys Limited . she has skills in \u2022 Good communication - written and oral skills . a degree in C.B.S.E., Bachelor of Technology in Information Technology .",
#         "Job Fit Score": 0.2804722487926483,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "PRASHANTH BADALA",
#         "Resume Summary": "PRASHANTH BADALA has a degree in B.Tech from Annamacharya Institute of Technology . she has skills in CHEF, AWS , weblogic, Docker, jenkins, devops, maven, svn .",
#         "Job Fit Score": 0.36660438776016235,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Pratibha P",
#         "Resume Summary": "Pratibha P has worked at Oracle, Oracle, and Oracle . she has skills in BI Publisher Reports, AP, HRMS, GL, Conversion, Oracle Apps technical, Interface, AR, TOAD, OLFM, SQL, FA ADDITIONAL INFORMATION .",
#         "Job Fit Score": 0.2506156861782074,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Prem Koshti",
#         "Resume Summary": "Prem Koshti has worked at SAP, SAP, saa, . . she has skills in Front End Tool Languages SAP Technologies HR and Administration Functional Module Database FOXPRO 6.22 Concepts OOP'S, Networking, DBMS, Operating System .",
#         "Job Fit Score": 0.3868476450443268,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Pulkit Saxena",
#         "Resume Summary": "Pulkit Saxena has worked at Cisco, Cisco, and Cisco . she has skills in  ADVANCED MS OFFICE (WORD, POWERPOINT, EXCEL, ETC).  JAVA NETBEANS, SQL, HTML, CMD PROMPT .",
#         "Job Fit Score": 0.41480758786201477,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Puneet Singh",
#         "Resume Summary": "Puneet Singh has worked at Oracle India Pvt Ltd . she has skills in Windows and Linux, Eclipse, PyCharm, Databases: Oracle, Mysql, Java, C, C++, Python, Batch, python, java .",
#         "Job Fit Score": 0.46043291687965393,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Rahul Bollu",
#         "Resume Summary": "Rahul Bollu has worked at Microsoft, HCL Technologies -, Disney . she has skills in Scripting Languages: Shell Scripted Configuration Management: Ansible . graduated from Vaughn College of Aeronautics and Technology with a degree in Bachelor Of Science .",
#         "Job Fit Score": 0.2353748083114624,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Rajeev Kumar",
#         "Resume Summary": "Rajeev Kumar has worked at Infosys - Pune, Maharashtra . has skills in Soft Skills Communicator, Innovator, Team Player, Analytical Collaborator . she has a degree in soft skills, communication and soft skills .",
#         "Job Fit Score": 0.34920835494995117,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ram Edupuganti",
#         "Resume Summary": "Ram Edupuganti has a degree in B.S. in Electronics & Communications Engineering . she has skills in UNIX, Windows, Linux , SQL, PL/SQL, HTML, XML, JAVA, JDK, J2EE .",
#         "Job Fit Score": 0.40804362297058105,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ramesh HP",
#         "Resume Summary": "Ramesh HP has worked at SAP ARIBA . she has skills in Lead genearation, Customer Handling, Cold calling, Negotiation, upselling, IT sales, outbound calling, sales forcasting, Software sale, cross selling, Inside Sales, Technical sales, MS office .",
#         "Job Fit Score": 0.26426178216934204,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ramya. P",
#         "Resume Summary": "narayana jr.college, vasundhara womens has a degree in BSc in computer science . she has skills in logging, Black Box, SQL, Database, java, SDLC&STLC, Manual Testing, Splunk, Nagious, SQL .",
#         "Job Fit Score": 0.32041803002357483,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "R Arunravi",
#         "Resume Summary": "R Arunravi has worked at SAP, SAP EWM, SAP . she has skills in . SAP Knowledge: SAP , SAP SD, SAP AFS . graduated from Anna University with a degree in Bachelor of Technology in Information Technology, Master of Engineering in Computer and Communication .",
#         "Job Fit Score": 0.25837239623069763,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ravi Shankar",
#         "Resume Summary": "Ravi Shankar has worked at Microsoft, Microsoft, . Microsoft, and Microsoft . she has skills in SCOM, Orchestrator SCSM, OPERATIONS MANAGER, SCOM . graduated from Pune university with a degree in B.E., B.e.",
#         "Job Fit Score": 0.30978158116340637,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ravi Shivgond",
#         "Resume Summary": "Ravi Shivgond has worked at SAP . she has skills in AC (Less than 1 year), GE FANUC . graduated from Govt. high school yernalli with a degree in B.E.",
#         "Job Fit Score": 0.18796998262405396,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Rohit Bijlani",
#         "Resume Summary": "Rohit Bijlani has worked at INFOSYS LIMITED . she has skills in . Graduated from ITM University Gwalior with a degree in Bachelor of Engineering in Mechanical Eng. she is a graduate of the university of .",
#         "Job Fit Score": 0.3350312113761902,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Roshan Sinha",
#         "Resume Summary": "Roshan Sinha has worked at OOPS-ABAP, SAP ABAP . she has a degree in B.Tech in technology . graduated from Anna University Chennai with a grade in b.tech in Technology .",
#         "Job Fit Score": 0.33902454376220703,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sai Dhir",
#         "Resume Summary": "Sai Dhir has worked at oraCLE -, ORACLE-, orACLE, Sasken Technologies Pvt. Ltd . has skills in Domain telecom Platform-windows Framework-filezilla, putty, CHANGE MANAGEMENT (Less than 1 year), Configuration Management, Git, Incident Management and Linux . she has a degree in Android, Bachelor of Engineering in Engineering .",
#         "Job Fit Score": 0.4299512505531311,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sai Patha",
#         "Resume Summary": "Sai Patha has worked at Arrow Electronics Inc . she has skills in Languages Java, Java Script, PL/SQL, SQL SERVER, HTML, XML and XSLT Application Servers J Boss, Apache Tomcat .",
#         "Job Fit Score": 0.46289151906967163,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sai Vivek Venkatraman",
#         "Resume Summary": "Sai Vivek Venkatraman has worked at Infosys Limited . she has a degree in BACHELOR OF ENGINEERING in ELECTRONICS & COMMUNICATION in BUSINESS .",
#         "Job Fit Score": 0.3327624797821045,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sameer Kujur",
#         "Resume Summary": "Sameer Kujur has worked at Microsoft . she has skills in Application Development, Software Testing . graduated from VSSUT,burla with a degree in Electrical engineering . he has a . degree in electrical engineering and is a graduate of the university .",
#         "Job Fit Score": 0.3150622546672821,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Samyuktha Shivakumar",
#         "Resume Summary": "Samyuktha Shivakumar has worked at the Mount Carmel Institute of Management . she has skills in Project Management, Product Marketing, Campaigns Management, Digital Marketing, Social Media Marketing, Marketing Operations, Content Marketing, Channels Operations, Marketo Admin User .",
#         "Job Fit Score": 0.2859146296977997,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Santosh Ganta",
#         "Resume Summary": "Santosh Ganta has worked at Infosys Limited . she has skills in Tools: ISPF, SPUFI, QMF, File-Aid, MainView, Librarian, CA7, Control-M, Xpeditor .",
#         "Job Fit Score": 0.2660160958766937,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sarfaraz Ahmad",
#         "Resume Summary": "Sarfaraz Ahmad has worked at ADDITIONAL INFORMATION Technical Skills Network . she has skills in BGP (2 years), EIGRP and security (2 years) she has a degree in H.S.C, bachelor of commerce in commerce .",
#         "Job Fit Score": 0.3987394869327545,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Senthil Kumar",
#         "Resume Summary": "Senthil Kumar has a degree in B.Tech in Computer Science in computer science . she has worked at Cisco, . Cisco, Cisco, and Cisco, as well as the . ACE Nexus 5k and ACI 9K switches .",
#         "Job Fit Score": 0.4256998598575592,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Shabnam Saba",
#         "Resume Summary": "Shabnam Saba has worked at SAP Labs . she has skills in CRM (10+ years), CUSTOMER RELATIONSHIP MANAGEMENT (10) and TESTING (10 + years), UI (10) . graduated from padmanava college of engineering .",
#         "Job Fit Score": 0.2744539976119995,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Shaheen Unissa",
#         "Resume Summary": "Shaheen Unissa has worked at JAWAHARLAL NEHRU TECHNOLOGICAL UNIVERSITY with skills in Classical and Interactive Reports . she has skills in BDC's, LSMW, BAPI, BADI, User Exits .",
#         "Job Fit Score": 0.2824092209339142,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sharan Adla",
#         "Resume Summary": "Sharan Adla has worked at Vignan Vidyalayam high school, Gowtham Jr. College -, M. V. G. R College of Engineering with a degree in SSC, MPC subject, Bachelors in Computer Science .",
#         "Job Fit Score": 0.21395230293273926,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Shreyanshu Gupta",
#         "Resume Summary": "Shreyanshu Gupta has worked at Amazon, Amazon, amazon, amazon . she has skills in GIT, HTML, PHP, Web Development, Velocity, Android, Java, SQL, C, JSP, Java .",
#         "Job Fit Score": 0.34543004631996155,
#         "Feedback": [
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Shrishti Chauhan",
#         "Resume Summary": "Shrishti Chauhan has a degree in C.S. from CHHATTISGARH SWAMI VIVEKANANDA TECHNICAL UNIVERSITY . she has skills in Oracle, Xml, Oracle MFT, Core Java, Oracle SOA, WSDL, ODI.",
#         "Job Fit Score": 0.38400405645370483,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Shubham Mittal",
#         "Resume Summary": "Shubham Mittal has worked at Infosys Limited . she has skills in Html, Css, Javascript, Salesforce . graduated from St. John's School with a degree in B.Tech in EEE .",
#         "Job Fit Score": 0.24809391796588898,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sivaganesh Selvakumar",
#         "Resume Summary": "Sivaganesh Selvakumar has worked at Infosys Limited . she has skills in TECHNICAL SKILLS: Platforms Windows, Unix, Linux Scripting Language PowerShell scripting, Shell scripting .",
#         "Job Fit Score": 0.4342610239982605,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Snehal Jadhav\n",
#         "Resume Summary": "Snehal Jadhav has skills in Architecture (Less than 1 year), DHCP, DNS, and EIGRP . ADDITIONAL INFORMATION Technical Skills \u2022 Layer 2 Technologies like VTP, VLAN, STP, and RSTP .",
#         "Job Fit Score": 0.4701097011566162,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Soumya Balan",
#         "Resume Summary": "Soumya Balan has skills in Linux (Less than 1 year), MS OFFICE and problem solving . she has a degree in state board , BTEC HNC in aviation in Hospitality and Travel Management, BE in Computer Science and Engineering.",
#         "Job Fit Score": 0.4189271032810211,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Soumya Balan",
#         "Resume Summary": "Soumya Balan has worked at Microsoft Corporation . she has skills in DBMS, O365, Communication Skills, Exchange 2013, Hospitality, Networking, Computer Operating, Programming, computer hardware, Exchange 2010, teaching ADDITIONAL INFORMATION Skill Set .",
#         "Job Fit Score": 0.4624614715576172,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sowmya Karanth",
#         "Resume Summary": "Sowmya Karanth has worked at EMEA ( Middle Eastern), NAMER ( North Americas'), Oracle India Pvt ltd . she has skills in ERP, Microsoft office, ERP, Oracle SQL, MS OFFICE . graduated from avinashilingam deemed university, S.B.K.V higher secondary school .",
#         "Job Fit Score": 0.28674665093421936,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Srabani Das",
#         "Resume Summary": "Srabani Das has worked at Oracle, Oracle, oracle, Oracle . she has skills in Databases (Primary): Teradata, Oracle (SQL, PL/sQL), BTEQ, Muti Load .",
#         "Job Fit Score": 0.3566088080406189,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Srinivas VO",
#         "Resume Summary": "Srinivas VO has worked at Kakatiya University, Nagarjuna . she has skills in Testing (10+ years), Program Management (10+ . years), Automation Testing (10+ years) and Selenium Webdriver (4 years), Project Management (10) .",
#         "Job Fit Score": 0.3339557349681854,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Srushti Bhadale",
#         "Resume Summary": "ADDITIONAL INFORMATION TECHNICAL SKILL SET: \u2022 Programming Languages: C, Java, JavaScript, SQL . graduated from Convent Girls' High School, D.G Ruparel College .",
#         "Job Fit Score": 0.3093995451927185,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sudaya Puranik",
#         "Resume Summary": "Sudaya Puranik has worked at Oracle India Private Limited, Company 1 . she has skills in Oracle Apps DBA Release Enginner , Databases: Oracle 9i/10g, MySql Languages: PL/SQL, Shell Script .",
#         "Job Fit Score": 0.2946670353412628,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sumit Kubade",
#         "Resume Summary": "Sumit Kubade has skills in Windows, Microsoft Word, Excel, Power point, Tally . graduated from Maharashtra State Government, Pune University, Indian Institute Of Company Secretory Of India (Appeared) with a degree in B.com .",
#         "Job Fit Score": 0.2053457498550415,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Syam Devendla",
#         "Resume Summary": "Syam Prasad Devendla has worked at Oracle India . she has skills in side debugging . Hands on experience of OOPS design principles and STL . experience of using various debuggers .",
#         "Job Fit Score": 0.3711812496185303,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Tejasri Gunnam",
#         "Resume Summary": "Tejasri Gunnam has worked at Cisco SystemsIndPvtLtd . she has skills in Databases: Oracle &SQL Server Operating System: MS-DOS, Windows 98/XP &UNIX, Windows 7 Languages: C, C++ Testing Tools: Q.T.P, Win Runner7.5 .",
#         "Job Fit Score": 0.4164982736110687,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Urshila Lohani",
#         "Resume Summary": "Urshila Lohani has worked at Oracle, Oracle , Oracle, mongoDB . she has skills in . graduated from college of engineering with a degree in B Tech Honors in Technical . a graduate of the university of london .",
#         "Job Fit Score": 0.3277375102043152,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Vamsi krishna",
#         "Resume Summary": "Vamsi krishna has worked at Microsoft . she has skills in Analytics, Research . graduated from Shri gnanambika degree college with a degree in Bsc in bsc .",
#         "Job Fit Score": 0.35732293128967285,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "VARUN AHLUWALIA",
#         "Resume Summary": "VARUN AHLUWALIA has worked at Tavant . she has skills in Programming, JAVA, C++, C, Matlab, SQL Operating System . graduated from Indian Institutes of Technology IIT Kanpur, university of Chicago .",
#         "Job Fit Score": 0.45173168182373047,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Vijayalakshmi Govindarajan",
#         "Resume Summary": "Vijayalakshmi Govindarajan has worked at SAP Basis, SAP Basis and SAP Basis . she has skills in JAVA (6 years), ORACLE (6 years) and ABAP (Less than 1 year)",
#         "Job Fit Score": 0.42225584387779236,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Vikas Singh",
#         "Resume Summary": "Vikas Singh has worked at Infosys Limited , Infosies Limited . she has skills in INFORMATION SECURITY (5 years), ACTIVE DIRECTORY (3 years) and UNIX (Less than 1 year)",
#         "Job Fit Score": 0.32900187373161316,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Yasothai Jayaramachandran",
#         "Resume Summary": "Yasothai Jayaramachandran has worked at Cisco Systems, Automation & Testing . she has skills in Programming Languages Python, TCL, Power Query, SQL, Shell Scripting, C# Concepts Networking, WAAS (Wan Optimization), WAAS on Router, WAE(Wide Area Engine), WCCP Protocol, Automation Framework ATS .",
#         "Job Fit Score": 0.4644466042518616,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Yathishwaran P",
#         "Resume Summary": "Yathishwaran P has skills in Reporting Tools BIRT, Cognos (Basics) Database Oracle Operating Systems Windows Languages SQL, JavaScripting Web Technologies Tools HTML SQL Developer, Eclipse, CODA (4 years), Database (4 years) graduated from Government Boys Higher Secondary School .",
#         "Job Fit Score": 0.33849748969078064,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
# ...
#         ]
#     },
#     {
#         "Name": "Akshay Dubey",
#         "Resume Summary": "Akshay Dubey has worked at MICROSOFT . she has skills in Programming Languages C# .NET, CPP, C Web Development ASP.NET . graduated from Sinhgad Institute with a degree in B.E.",
#         "Job Fit Score": 0.34908807277679443,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sayani Goswami",
#         "Resume Summary": "Sayani Goswami has worked at MICROSOFT . she has skills in . graduated from periyar university with a degree in a . . degree in the . sciences . her work has been a part of .",
#         "Job Fit Score": 0.21438391506671906,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Sweety Garg",
#         "Resume Summary": "Sweety Garg has worked at Microsoft , Microsoft, Microsoft . she has skills in Expertise in Microsoft Office Power Point, Microsoft Office Word.  Basic knowledge about C and C++ Programming . graduated from SRM university with a degree in B.Tech in engineering .",
#         "Job Fit Score": 0.27118247747421265,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ramkrishan Bhatt",
#         "Resume Summary": "Ramkrishan Bhatt has skills in . graduated from affiliated - Kota, Rajasthan with a . degree in BCA, Mongo . she has a bachelor's degree in bCA, .",
#         "Job Fit Score": 0.17467783391475677,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "B. Gokul",
#         "Resume Summary": "B. Gokul has worked at Microsoft, Microsoft . she has skills in Microsoft word 2010, MICROSOFT WORD (Less than 1 year), MS EXCEL and WORD . graduated from periyar university with a degree in B.SC .",
#         "Job Fit Score": 0.19673039019107819,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Anand S",
#         "Resume Summary": "anand S has worked at Microsoft . she has skills in Good listener,take up responsibilities,good communication,great at taking challenges,excellent in various sports like soccer,cricket,kabbadi,cycling,running,swimming, fluent in English,kannada .",
#         "Job Fit Score": 0.33846452832221985,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Krishna Prasad",
#         "Resume Summary": "Krishna Prasad has worked at Microsoft . she has a degree in . BSc in Computer Science . has been a professor at magadh university . her work has been done at microsoft .",
#         "Job Fit Score": 0.3365647494792938,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Saurabh Sandhikar",
#         "Resume Summary": "SKILLS SQL MS Excel HTML Javascript, HTML (Less than 1 year), JAVASCRIPT, MS EXCEL and SQL . graduated from Gandhi Institute of Science and Technology (GITAM) university with a degree in B.Tech .",
#         "Job Fit Score": 0.27051064372062683,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Priyesh Dubey",
#         "Resume Summary": "Priyesh Dubey has worked at Microsoft, Microsoft, microsoft, cognizant . has skills in Microsoft Technologies C#.Net, WPF, WCF, ASP.Net MVC, Web API, Biztalk Server 2013 Cloud Azure Version Control Git, VSTS, SVN .",
#         "Job Fit Score": 0.36083900928497314,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Laya A",
#         "Resume Summary": "Laya has skills in HR (9 years), RECRUITMENT (1 year), DETAIL ORIENTED (Less than 1 year) ADDITIONAL INFORMATION CORE COMPETENCIES \u2022 Performance Management \u2022 Recruitment & Retention \u2022 Training & Development \u2022 HR Policies & Procedures .",
#         "Job Fit Score": 0.18344144523143768,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Vishwanath P",
#         "Resume Summary": "Vishwanath P has worked at LabourNet Services India Pvt Ltd . she has skills in . graduated from V V Pura College of Science with a degree in BSc, bc .",
#         "Job Fit Score": 0.2783243954181671,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Hemil Bhavsar",
#         "Resume Summary": "Hemil Bhavsar has skills in Technical skillset: \u2022 Manual Testing Techniques \u2022 Web Application testing \u2022 STLC (Software Testing Life Cycle) process \u2022 Verification and Validation process \u2022 Programming Language: Software Testing, ASP.Net with C# .",
#         "Job Fit Score": 0.22754380106925964,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Siddhartha Chetri",
#         "Resume Summary": "Siddhartha Chetri has worked at Partner Sites Infosys, Concentrix, Merchants and Convergys Collabera Technologies- Client- Cisco Systems, Inc. she has skills in REMEDY (3 years), CLARIFY (Less than 1 year), EXCEL (Lesess than one year), OUTLOOK (Leess over 1 year) ADDITIONAL INFORMATION Skill Set: Systems: Windows [...] 10)",
#         "Job Fit Score": 0.37381622195243835,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Pratik Vaidya",
#         "Resume Summary": "Pratik Vaidya has worked at allscripts . she has skills in Linux . graduated from Maharashtra institute of Technology with a degree in Btech . a u.s. embassy in syria is a member of the government .",
#         "Job Fit Score": 0.2354165017604828,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ramakrishna Rao",
#         "Resume Summary": "Ramakrishna Rao has worked at Tech Mahindra Ltd, Tech Mahinedra Ltd and .Net 4.5 (Less than 1 year), amazon Elastic Block Storage and ASP . she has a degree in B.Sc. in M.P.C . in computer applications .",
#         "Job Fit Score": 0.2378041297197342,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Keshav Dhawale",
#         "Resume Summary": "Keshav Dhawale has worked at TCS Hinjewadi Mail Room Boy & HK Store . she has skills in . graduated from board (university) with a degree in SSC .",
#         "Job Fit Score": 0.24477127194404602,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Praveen Bhaskar",
#         "Resume Summary": "Praveen Bhaskar has skills in MENTORING, TRAINING, PROGRAM MANAGER and PROJECT MANAGEMENT . ADDITIONAL INFORMATION Skills Project Management, People Management, Stake Holder Management, Vendor Management, Project Planning Scheduling and Implementation, Risk Analysis, Cross-functional supervision, Team building and mentoring .",
#         "Job Fit Score": 0.23763005435466766,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Gunjan Nayyar",
#         "Resume Summary": "Gunjan Nayyar has worked at INFOSYS . she has skills in . graduated from Chitkara university with a . degree in B. E. in CSE . he has a degree in b. e. in cSE.",
#         "Job Fit Score": 0.2845046818256378,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Rupesh Reddy",
#         "Resume Summary": "Rupesh Reddy has worked at EIT Services India Private Limited . she has skills in Soft Skills: \u2022 Cross Cultural Sensitivity \u2022 Written Communication Skills \u2022 Articulation Skills \u2022 Effective Meetings . graduated from Sri Venkateswara College of Engineering and Technology Affiliated .",
#         "Job Fit Score": 0.2612265646457672,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Puneeth R",
#         "Resume Summary": "Puneeth R has worked at HiPower Support Centre . she has skills in . graduated from PES College of Engineering - with a . degree in B.E. in b.e. in engineering .",
#         "Job Fit Score": 0.1799742728471756,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Kandrapu Reddy",
#         "Resume Summary": "Kandrapu Reddy has worked at international travel house Limited . she has skills in AMADEUS, CLIENT MANAGEMENT, EXCEL and MS WORD . graduated with a degree in B.B.A in airport & customer care management .",
#         "Job Fit Score": 0.22088101506233215,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Vineeth Vijayan",
#         "Resume Summary": "Vineeth Vijayan has skills in Storekeeping / Inventory Management / Purchase (2 years), People & Time Management (2 years) ADDITIONAL INFORMATION Competencies  Effective communications skills, excellent interpersonal skills, good time management skills, results-oriented individual and a very good team player .",
#         "Job Fit Score": 0.2788844704627991,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Rahul Tayade",
#         "Resume Summary": "Rahul Tayade has worked at Infosys Ltd . she has skills in MENTORING, SCHEDULING, ORACLE, SOLUTIONS and BENEFITS . graduated from Technical Board of Education Bombay .",
#         "Job Fit Score": 0.418479859828949,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Debasish Dasgupta",
#         "Resume Summary": "Debasish Dasgupta has worked at Infosys, Infosies, InfoSys . she has skills in . graduated from with a degree in a . . degree in the . sciences .",
#         "Job Fit Score": 0.24334348738193512,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Suresh Kanagala",
#         "Resume Summary": "Suresh Kanagala has worked at IBM , CSC . she has skills in operating systems Windows and Unix Configuration management tools VB, ASP, VB.net, C#, JavaScript, Jquery and Angular JS (Starter)",
#         "Job Fit Score": 0.4783896207809448,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Jaspreet Kaur",
#         "Resume Summary": "Jaspreet Kaur has worked at HR executive, HR Executive, Oceanic Consultants . has skills in Technical Skills OS Windows XP, Vista Others Microsoft word/excel/power point, Basic computer skills, Tally .",
#         "Job Fit Score": 0.22969822585582733,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Somanath Behera",
#         "Resume Summary": "Somanath Behera has worked at Cognizant technology Solutions . she has skills in Oracle Pl/Sql (6 years), Facets (3 years), Hadoop (1 year), healthcare (4 years), Informatica (6 years) ADDITIONAL INFORMATION Technical Skills: Operating System Unix and Windows Programming languages Unix Scripting, SQL and PL/SQL, Core Java .",
#         "Job Fit Score": 0.37675032019615173,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Ashish Indoriya",
#         "Resume Summary": "Ashish Indoriya has worked at Infosys Limited . she has skills in Java, SQL, J2EE, Sping, Hibernate, JavaScript, HTML, CSS ADDITIONAL INFORMATION Serving notice period .",
#         "Job Fit Score": 0.2619667053222656,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Dilliraja Baskara",
#         "Resume Summary": "Dilliraja Baskara has worked at Infosys . she has skills in mainframe,COBOL,JCL,DB2,IMSDB,IMSDC . graduated from panimalar engineering college with a degree in B.E.",
#         "Job Fit Score": 0.34298232197761536,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Deepika S",
#         "Resume Summary": "Deepika S has worked at Infosys Ltd . she has skills in . graduated from Bharathiyar university with a . degree in B.Sc. in Computer Science . also has a bachelor's degree in computer science .",
#         "Job Fit Score": 0.3268115222454071,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Jacob Philip",
#         "Resume Summary": "Jacob Philip has worked at sun infosys . she has skills in Excel (Less than 1 year), Word (less than one year) graduated from with a degree in bachelor's degree in britain .",
#         "Job Fit Score": 0.18385633826255798,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     },
#     {
#         "Name": "Yogesh Ghatole",
#         "Resume Summary": "Yogesh Ghatole has worked at Site at Shendra MIDC Aurangabad - Perkins India Ltd . she has skills in 40 WPM (Less than 1 year), AUTOCAD, EXCEL and MS OFFICE . completed successfully MS-CIT MS Office - Basic Computer Course .",
#         "Job Fit Score": 0.2861895263195038,
#         "Feedback": [
#             "Consider adding Java-related skills to the resume.",
#             "Consider adding Database-related skills to the resume."
#         ]
#     }
# ]
